# %% [markdown]
# # NER and PoS tagging with spaCy

# %% [markdown]
# spaCy is a widely used and user-friendly NLP library for certain core NLP tasks such as part-of-speech (POS) tagging and named-entitiy recognition (NER). In these next few weeks, we'll increasingly be using spaCy for these and related tasks.
#
# One thing to know (and like!) about spaCy is that it relies on machine learning models trained on large amounts of carefully-labeled text. (This is in contrast to LLMs which "learn" language features in other ways.) The English-language spaCy model that we’re going to use in this lesson was trained on an annotated corpus called “OntoNotes”: 2 million+ words drawn from “news, broadcast, talk shows, weblogs, usenet newsgroups, and conversational telephone speech,” which were meticulously tagged by a group of researchers and professionals for people’s names and places, for nouns and verbs, for subjects and objects, and much more.
#
# Another thing to know (but maybe not like?!) about spaCY is that, like a lot of other major machine learning projects, OntoNotes was sponsored by the Defense Advaced Research Projects Agency (DARPA), the branch of the Defense Department that develops technology for the U.S. military. So, in short, it's complicated!
#
# In any case, let's get started.

# %% [markdown]
# ### Loading the language model
#
# To load spaCy and its English-language model (`en_core_web_sm`), we need to do the following:

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# ### Processing a document

# %% [markdown]
# To get started with spaCy, we first need to process our document with the loaded NLP model. As with the tokenization for word2vec and our BERT experiments, most of the heavy lifting is done in this single line of code--and not by us, thankfully!
#
# After processing, the document object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our class will be devoted to accessing this information.
#
# Let's create a `Document` object with a few sentences from the Universal Declaration of Human Rights:

# %%
doc = nlp("""All human beings are born free and equal in dignity and rights.
They are endowed with reason and conscience and should act towards one another in
a spirit of brotherhood. Everyone has the right to life, liberty and security of person.""")

# %% [markdown]
# ## What can we do with spaCy?

# %% [markdown]
# ### Sentences
#
# spaCy offers an easy way to identify sentences with its `.sents` method. `doc.sents` will turn the doc into a list of sentences. Once you've created a document object, you can iterate over the sentences it contains using the `.sents` attribute as follows:

# %%
print("Here is the doc: ")
print(doc)
print("\n")
print("And here are the doc's sentences: ")

for sent in doc.sents:
    print(sent.text)
# Out:
# Here is the doc:
# All human beings are born free and equal in dignity and rights.
# They are endowed with reason and conscience and should act towards one another in
# a spirit of brotherhood. Everyone has the right to life, liberty and security of person.
#
#
# And here are the doc's sentences:
# All human beings are born free and equal in dignity and rights.
#
# They are endowed with reason and conscience and should act towards one another in
# a spirit of brotherhood.
# Everyone has the right to life, liberty and security of person.

# %% [markdown]
# Nerdy Python note: The `.sents` attribute is a [generator](https://wiki.python.org/moin/Generators), so you can't index or count it directly. Generator functions are also known as "lazy iterators," which are objects that you can loop over like a list, but do not store their contents in memory. This may seem like a bug right now, but it's actually a feature because it's a way of saving memory when you're dealing with large amounts of text.
#
# To index or count the .sents attribute, you'll need to convert it to a list first using the `list()` function. Then you can treat it like a list and access individual items:

# %%
sentences_as_list = list(doc.sents)

# %%
# check the length to make sure it worked

print("Here's the number of sentences: " + str(len(sentences_as_list)))
# Out:
# Here's the number of sentences: 3

# %% [markdown]
# ### Words
#
# Iterating over a document (or a sentence) yields each word in turn. Words are represented with spaCy [Token](https://spacy.io/docs/api/token) objects, which have several interesting attributes.
#
# The `.text` attribute gives the word, and the `.lemma_` attribute gives the word's "lemma."
#
# Wait, what's a "lemma"?!
#
# Here are Daniel Jurafsky and James H. Martin on the subject:
#
# > **Lemmas and Senses**
# >
# > Let’s start by looking at how one word (we’ll choose "mouse") might be defined in a dictionary:
# >
# > mouse (N)
# > 1.  any of numerous small rodents...
# > 2.  a hand-operated device that controls a cursor...
# >
# > Here the form "mouse" is the `lemma`, which is also called the "citation form." The form "mouse" would also be the lemma for the word "mice." One way to think about it is that dictionaries don’t have separated definitions for inflected forms like mice.
# >
# >Similarly, "sing" is the lemma for "sing," "sang," and "sung." In many languages, the infinitive form is used as the lemma for the verb, so Spanish dormir “to sleep” is the lemma for duermes “you sleep”. The specific forms _sung_ or _carpets_ or _sing_ or _duermes_ are called `wordforms`."
#
# Let's see how the words and lemmas compare in our tiny document:

# %%
print("Word, lemma\n")
for word in doc:
    print(word.text + ", " + word.lemma_)

# Note: On the underscore at the end of a variable, see
# https://www.datacamp.com/community/tutorials/role-underscore-python#STU
# Out:
# Word, lemma
#
# All, all
# human, human
# beings, being
# are, be
# born, bear
# free, free
# and, and
# equal, equal
# in, in
# dignity, dignity
# and, and
# rights, right
# ., .
#
# ,
#
# They, they
# are, be
# endowed, endow
# with, with
# reason, reason
# and, and
# conscience, conscience
# and, and
# should, should
# act, act
# towards, towards
# one, one
# another, another
# in, in
#
# ,
#
# a, a
# spirit, spirit
# of, of
# brotherhood, brotherhood
# ., .
# Everyone, everyone
# has, have
# the, the
# right, right
# to, to
# life, life
# ,, ,
# liberty, liberty
# and, and
# security, security
# of, of
# person, person
# ., .

# %% [markdown]
# As indicated above, we can also interate through the document by sentence. To wit:

# %%
sentence = list(doc.sents)[1]  # same as sentence = sentences_as_list[1]

for word in sentence:
    print(word.text, word.lemma_)
# Out:
# They they
# are be
# endowed endow
# with with
# reason reason
# and and
# conscience conscience
# and and
# should should
# act act
# towards towards
# one one
# another another
# in in
#
#
#
# a a
# spirit spirit
# of of
# brotherhood brotherhood
# . .

# %% [markdown]
# Why does this distinction between "word" and "lemma" matter? Well for one, at certain times you might want to be able to gather all of the wordforms of a single word together so that you could count them as a single unit. This will come into play as we start counting words in various ways...
#
# But first:

# %% [markdown]
# ### How to load data from a file into spaCy
#
# You can load data from a file easily with spaCy, which is good because most of the text we want to analyze comes to us in file form.
#
# Today's first exercise will focus on a timely topic, which is US political party platforms. I've created flat text files of the 2024 platforms for both Republicans and Democrats as archived through the [American Presidency Project website](https://www.presidency.ucsb.edu/documents/app-categories/elections-and-transitions/party-platforms).

# %%
# get the text of the 2024 Democratic platform from GitHub
import requests

resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall24/refs/heads/main/corpora/platforms/democrat_platform_2024.txt')
dem_platform = resp.text

# %% [markdown]
# Next, let's turn the text into a spaCy document, as we did before:

# %%
dem_plat_doc = nlp(dem_platform)

# %% [markdown]
# ...and do the same thing for the 2024 Republican platform:

# %%
resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall24/refs/heads/main/corpora/platforms/republican_platform_2024.txt')
repub_platform = resp.text

repub_plat_doc = nlp(repub_platform)

# %% [markdown]
# ## Counting keywords (with custom code)
#
# We've learned other ways to do this (e.g. sk-learn's countVectorizer), but since basic counting will help us on the way to figuring out why named entity recognition is useful, let's think about a clear scenario: if we want to know how many times President Biden was named in the Democratic platform vs. the Republican platform, we could do something like this:

# %%
# define a basic function to count words

def count_words(keyword, document): # this says: we'll always pass in a keyword to search for
                                    # and a spacy document to search
    # here's our keyword hit counter
    key_count = 0

    # iterate through all the words in the document
    for word in document:
        cur_word = word.text # remember, word is an object so you need to look at word.text

        # see if the keyword matches the word, and if so, increment our counter;
        if keyword.lower() == cur_word.lower(): # note that this is just a basic string comparison

            # if there's a match, increment the keyword counter by 1
            key_count += 1

    # this returns the final keyword count
    return key_count

# %%
# now call our newly defined function for the dem_plat_doc and the repic_plat_doc

num_d_bidens = count_words("Biden", dem_plat_doc)
num_r_bidens = count_words("Biden", repub_plat_doc)

print("Number of Biden mentions in Democratic platform: " + str(num_d_bidens))
print("Number of Biden mentions in Republican platform: " + str(num_r_bidens))
# Out:
# Number of Biden mentions in Democratic platform: 287
# Number of Biden mentions in Republican platform: 7

# %% [markdown]
# But what if we wanted to see which people were named in each platform, but we didn't know how to search for them by name? This is where NER comes in.

# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# Identifying sentences and words is just the beginning of what spaCy can do. Also encoded in the spaCy `document` is a great deal of information about named entities: that is, about people, places, and many types of things. This is what's known as "Named Entity Recognition," or NER.
#
# You might use NER to identify the geographic locations mentioned in texts, a first step toward mapping them. Or you might use NER to identify the most frequently appearing characters in a novel, or to build a network of characters that appear together. Or you might use NER in a more exploratory capacity, as in the scenario I've outlined above.
#
# Below is a Named Entities chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different named entities that spaCy can identify, as well as their corresponding "type labels."
#
# Note that "PERSON"--what we're going to look for in a sec--is just one of many different named entities that spaCy can recognize.
#
# Let's try it out.

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|
# |NORP|Nationalities or religious or political groups.|
# |FAC|Buildings, airports, highways, bridges, etc.|
# |ORG|Companies, agencies, institutions, etc.|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|
# |PRODUCT|Objects, vehicles, foods, etc. (Not services.)|
# |EVENT|Named hurricanes, battles, wars, sports events, etc.|
# |WORK_OF_ART|Titles of books, songs, etc.|
# |LAW|Named documents made into laws.|
# |LANGUAGE|Any named language.|
# |DATE|Absolute or relative dates or periods.|
# |TIME|Times smaller than a day.|
# |PERCENT|Percentage, including ”%“.|
# |MONEY|Monetary values, including unit.|
# |QUANTITY|Measurements, as of weight or distance.|
# |ORDINAL|“first”, “second”, etc.|
# |CARDINAL|Numerals that do not fall under another type.|

# %% [markdown]
# Here's how we pull out all of the people mentioned in the Democratic platform using the `ents` method (short for "entitites"):

# %%
# an empty list we'll use to store the people
people = []

# iterate through all the words in the document (note this could also be sentences)
for ent in dem_plat_doc.ents: # this is a method that turns the doc into entitites
    if ent.label_ == "PERSON": # again, here's basic string comparison
        if ent.text not in people: # we'll only add new people
            people.append(ent.text)

people
# Out:
# ['Menominee',
#  'Fox',
#  'Wea',
#  'Shab',
#  'Biden',
#  'Harris',
#  'Donald Trump',
#  'Joe Biden',
#  'Herbert Hoover',
#  'John F. Kennedy',
#  'Trump',
#  'Prescription Drugs',
#  'Head Start',
#  'Paid Leave\n\n',
#  'GREED',
#  'Glass',
#  'Volcker',
#  'Black-',
#  'RESILIENT COMMUNITIES',
#  'Gabon',
#  "Donald Trump's",
#  "George Floyd's",
#  'marijuana',
#  'Pell Grants',
#  'Steve Bannon',
#  'Roger Stone',
#  'Paul Manafort',
#  'Michael Flynn',
#  'Charles Kushner',
#  'Ketanji Brown Jackson',
#  'Jackson',
#  'Latino',
#  'Summer EBT',
#  'Latino-owned',
#  'Pell Grant',
#  'PrEP',
#  'Abuse',
#  'Olmstead',
#  'Berryessa Snow Mountain',
#  'Deborah Lipstadt',
#  'Sikh',
#  'Nick Fuentes',
#  'Hitler',
#  'Rashad Hussain',
#  'Neighborhood Partnerships',
#  'Kennedy Center',
#  'Shut Down',
#  'K-1',
#  'K-2',
#  'K-3',
#  'Obama',
#  'Temporary Protected Status',
#  'Cancer',
#  'The Cancer Moonshot',
#  'Sexual Assault',
#  'Executive Order',
#  'Vladimir Putin',
#  'Putin',
#  'Vilnius',
#  'Zelenskyy',
#  'Comprehensive Strategic Partnerships',
#  'Kim Jong Un',
#  'Ayman al-Zawahiri',
#  'Nicolás Maduro',
#  'Prosper Africa',
#  'Coast Guardsmen']

# %% [markdown]
# **Can you modify the code above to pull out the people named in the Republican platform?**

# %%
# your code here
# hint: start by copying the code above

# %%
# an empty list we'll use to store the people
people = []

# iterate through all the words in the document (note this could also be sentences)
for ent in repub_plat_doc.ents: # this is a method that turns the doc into entitites
    if ent.label_ == "PERSON": # again, here's basic string comparison
        if ent.text not in people: # we'll only add new people
            people.append(ent.text)

people
# Out:
# ['Donald J. Trump',
#  'Trump',
#  'Biden',
#  'Common Sense',
#  'Joe Biden',
#  'Agenda',
#  'POLITICAL',
#  'Good Grace',
#  'Illegal Aliens',
#  'Aliens',
#  'Migrant Crime',
#  'Law',
#  'Fentanyl Blockade',
#  'Remain',
#  'Chain Migration',
#  'Tax Cuts',
#  'Supply Chains',
#  'Energy Dominant',
#  'Crypto',
#  'Bitcoin',
#  "Joe Biden's",
#  'Executive Order',
#  'Radical Leftwing',
#  'Moon',
#  'Strategic Independence',
#  'Strong',
#  'Jobs',
#  'Buy American',
#  'Hire American',
#  'Hire American Policies',
#  'Healthy Living',
#  'Math',
#  'Veterans',
#  'American History',
#  'Taxpayer',
#  'Radical Left',
#  'Due Process',
#  'Schools',
#  'Treasures',
#  'Lawful Speech',
#  'Voter']

# %% [markdown]
# **Python Bonus! Looking at the syntax of the function above, can you write a function that will pull out the people in any document?**

# %%
# your code here

# %% [markdown]
# ## Visualizing spaCy NER with displaCy
#
# Here's a neat thing! To quickly see spaCy's NER in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) with the `style=` parameter set to "ent" to see how spaCy tags its documents. (DisplaCy is special spaCy module for visualization).

# %% [markdown]
# To do so, we’re going to need to import displaCy, Also, because the `spaCy` code expects all strings to be unicode strings, per above, we can also include `from __future__ import unicode_literals` to make our lives easier.

# %%
from __future__ import unicode_literals
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %%
displacy.render(dem_plat_doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democratic Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Platform<br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 19, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democratic National Convention
# Land Acknowledgement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Democratic National Committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  wishes to acknowledge that we gather together to state our values on lands that have been stewarded through
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     many centuries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by the ancestors and descendants of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tribal Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  who have been here since time immemorial. We honor the communities native to this continent, and recognize that our country was built on Indigenous homelands. We pay our respects to the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of Indigenous people throughout history who have protected our lands, waters, and animals.<br><br>While we meet in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chicago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , we also recognize and honor the traditional homelands of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anishinaabe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , also known as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Council of the Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Fires: the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ojibwe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odawa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potawatomi Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>We acknowledge the many other tribes who consider this area their traditional homeland, including the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Myaamia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ho-Chunk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Menominee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Sac and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peoria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kaskaskia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kickapoo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and Mascouten.<br><br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  continue to support tribes as they advocate for
# <mark class="entity" style="background: #feca74; padding:

# %% [markdown]
# Pretty neat, huh? Except, it's not completely perfect...
#
# **Can you find some examples of things it misidentified?**
#
# (You can scroll through the introductory material if you need to).

# %% [markdown]
# This is a good reminder than spaCy is far from perfect and you always need to check how it does!
#
# This is all we're going to do with NER today. As you can see this is just the very tip of the iceberg. You could now easily get, say, a full list of persons or orgs or products from any text. Feel free to explore further on your own.

# %% [markdown]
# ## Dictionaries
#
# One other basic way to analyze text is through what's known as a dictionary. (Not a Python dictionary!). As we learned in a previous quiz, this is just a set of words that evoke some category, optionally paired with a rating on some scale.
#
# Even though there are now fancier ways to categorize langugage, dictionaries are still widely used--and to sometimes profound effect.
#
# The words that constitute a dictionary are determined according to a wide range of methods, from completely hand-crafted, to semi-supervised, to fully "learned" (by computers).
#
# Let's look at a simple example.
#
# Here we'll define our own "immigration" dictionary by picking some words that we think have to do with the topic of immigration. (On the scale of hand-crafted to learned, this one is *extremely* hand-crafted).

# %%
immigration_dictionary=set(["wall", "border", "borders", "immigrants","immigration"])

# %% [markdown]
# We can actully use our previously defined `count_words` function to search both party platforms for how they stack up against the immigration dictionary:

# %%
dem_counts = 0
repub_counts = 0

for word in immigration_dictionary:
    dem_counts += count_words(word, dem_plat_doc)
    repub_counts += count_words(word, repub_plat_doc)

print("Immigratation scores:")
print("Dems: " + str(dem_counts))
print("Repubs: " + str(repub_counts))
# Out:
# Immigratation scores:
# Dems: 87
# Repubs: 41

# %% [markdown]
# Interesting! For our (flimsy) definition of immmigration, the Democratic platform seem to have mentioned it more than the Republican platform at a ratio of just about 2:1. But that may be due to the different lengths of the docs. So let's just normalize the counts before moving on.

# %%
print("Normalized immigratation scores:")
print("Dems: " + str(dem_counts / len(dem_plat_doc)))
print("Repubs: " + str(repub_counts / len(repub_plat_doc)))
# Out:
# Normalized immigratation scores:
# Dems: 0.0017413234057883991
# Repubs: 0.006391270459859704

# %% [markdown]
# # Part-of-Speech Tagging
#
# I've left part-of-speech (PoS) tagging until last because it's simultaneously very useful, very complicated (unless you're a big grammar nerd), and very boring (again, unless you're a big grammar nerd).
#
# Why should we bother? Well, for one, parts of speech are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence. By computationally identifying parts of speech, we can start computationally exploring syntax, the relationship between words — rather than only focusing on words in isolation.
#
# I've attempted to make this lesson more exciting by including some dymanically-generated brightly colored charts and some [xkcd](https://xkcd.com/1443/). Buckle up!

# %% [markdown]
# <img src="https://imgs.xkcd.com/comics/language_nerd.png" >

# %% [markdown]
# ## Part-of-Speech Tagging with spaCy
#
# In spaCy, POS tagging works much likes NER tagging. Here is a chart (which resembles the NER chart) of which parts of speech spaCy is able to recognize and identify:

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# You can access the POS for any word using the `pos_` attribute. If you want a more specific designation, you can use the `tag_` attribute.
#
# Note that this *is* slightly different than accessing NER tags, which requires that you start with the document's entities (`document.ents`) rather than the document itself. There are technical reasons for this that I can explain if you're curious.

# %% [markdown]
# ### Enough talk. Let's see POS tagging in action!
#
# Let's look at the parts-of-speech in the Republican party platform.

# %%
print("Word, POS, tag\n")

for word in repub_plat_doc:
    print(word.text, word.pos_, word.tag_)
# Out:
# Streaming output truncated to the last 5000 lines.
# worst ADJ JJS
# Inflation NOUN NN
# crisis NOUN NN
# in ADP IN
# four NUM CD
# decades NOUN NNS
# that PRON WDT
# has AUX VBZ
# crushed VERB VBN
# the DET DT
# middle ADJ JJ
# class NOUN NN
# , PUNCT ,
# devastated VERB VBN
# family NOUN NN
# budgets NOUN NNS
# , PUNCT ,
# and CCONJ CC
# pushed VERB VBD
# the DET DT
# dream NOUN NN
# of ADP IN
# homeownership NOUN NN
# out ADP IN
# of ADP IN
# reach NOUN NN
# for ADP IN
# millions NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# defeat VERB VB
# Inflation NOUN NN
# , PUNCT ,
# tackle VERB VB
# the DET DT
# cost NOUN NN
# - PUNCT HYPH
# of ADP IN
# - PUNCT HYPH
# living NOUN NN
# crisis NOUN NN
# , PUNCT ,
# improve VERB VB
# fiscal ADJ JJ
# sanity NOUN NN
# , PUNCT ,
# restore VERB VB
# price NOUN NN
# stability NOUN NN
# , PUNCT ,
# and CCONJ CC
# quickly ADV RB
# bring VERB VB
# down ADP RP
# prices NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# Inflation NOUN NN
# is AUX VBZ
# a DET DT
# crushing VERB VBG
# tax NOUN NN
# on ADP IN
# American ADJ JJ
# families NOUN NNS
# . PUNCT .
# History NOUN NN
# shows VERB VBZ
# that SCONJ IN
# Inflation NOUN NN
# will AUX MD
# not PART RB
# magically ADV RB
# disappear VERB VB
# while SCONJ IN
# policies NOUN NNS
# remain VERB VBP
# the DET DT
# same ADJ JJ
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# unleashing VERB VBG
# American PROPN NNP
# Energy PROPN NNP
# , PUNCT ,
# reining VERB VBG
# in ADP IN
# wasteful ADJ JJ
# spending NOUN NN
# , PUNCT ,
# cutting VERB VBG
# excessive ADJ JJ
# Regulations PROPN NNPS
# , PUNCT ,
# securing VERB VBG
# our PRON PRP$
# Borders PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# restoring VERB VBG
# Peace NOUN NN
# through ADP IN
# Strength PROPN NNP
# . PUNCT .
# Together ADV RB
# , PUNCT ,
# we PRON PRP
# will AUX MD
# restore VERB VB
# Prosperity PROPN NNP
# , PUNCT ,
# ensure VERB VB
# Economic PROPN NNP
# Security PROPN NNP
# , PUNCT ,
# and CCONJ CC
# build VERB VB
# a DET DT
# brighter ADJ JJR
# future NOUN NN
# for ADP IN
# American PROPN NNP
# Workers PROPN NNPS
# and CCONJ CC
# their PRON PRP$
# families NOUN NNS
# . PUNCT .
# Our PRON PRP$
# dedication NOUN NN
# to ADP IN
# these DET DT
# Policies PROPN NNPS
# will AUX MD
# make VERB VB
# America PROPN NNP
# stronger ADJ JJR
# , PUNCT ,
# more ADV RBR
# resilient ADJ JJ
# , PUNCT ,
# and CCONJ CC
# more ADV RBR
# prosperous ADJ JJ
# than ADP IN
# ever ADV RB
# before ADV RB
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Unleash PROPN NNP
# American PROPN NNP
# Energy PROPN NNP
#
#
#  SPACE _SP
# Under ADP IN
# President PROPN NNP
# Trump PROPN NNP
# , PUNCT ,
# the DET DT
# U.S. PROPN NNP
# became VERB VBD
# the DET DT
# Number PROPN NNP
# One NUM CD
# Producer PROPN NNP
# of ADP IN
# Oil PROPN NNP
# and CCONJ CC
# Natural PROPN NNP
# Gas PROPN NNP
# in ADP IN
# the DET DT
# World PROPN NNP
# — PUNCT :
# and CCONJ CC
# we PRON PRP
# will AUX MD
# soon ADV RB
# be AUX VB
# again ADV RB
# by ADP IN
# lifting VERB VBG
# restrictions NOUN NNS
# on ADP IN
# American PROPN NNP
# Energy PROPN NNP
# Production PROPN NNP
# and CCONJ CC
# terminating VERB VBG
# the DET DT
# Socialist PROPN NNP
# Green PROPN NNP
# New PROPN NNP
# Deal PROPN NNP
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# unleash VERB VB
# Energy PROPN NNP
# Production PROPN NNP
# from ADP IN
# all DET DT
# sources NOUN NNS
# , PUNCT ,
# including VERB VBG
# nuclear ADJ JJ
# , PUNCT ,
# to PART TO
# immediately ADV RB
# slash VERB VB
# Inflation NOUN NN
# and CCONJ CC
# power NOUN NN
# American ADJ JJ
# homes NOUN NNS
# , PUNCT ,
# cars NOUN NNS
# , PUNCT ,
# and CCONJ CC
# factories NOUN NNS
# with ADP IN
# reliable ADJ JJ
# , PUNCT ,
# abundant ADJ JJ
# , PUNCT ,
# and CCONJ CC
# affordable ADJ JJ
# Energy PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Rein NOUN NN
# in ADP IN
# Wasteful PROPN NNP
# Federal PROPN NNP
# Spending PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# immediately ADV RB
# stabilize VERB VB
# the DET DT
# Economy PROPN NNP
# by ADP IN
# slashing VERB VBG
# wasteful ADJ JJ
# Government NOUN NN
# spending NOUN NN
# and CCONJ CC
# promoting VERB VBG
# Economic PROPN NNP
# Growth PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Cut VERB VB
# Costly PROPN NNP
# and CCONJ CC
# Burdensome PROPN NNP
# Regulations PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# reinstate VERB VB
# President PROPN NNP
# Trump PROPN NNP
# 's PART POS
# Deregulation PROPN NNP
# Policies PROPN NNPS
# , PUNCT ,
# which PRON WDT
# saved VERB VBD
# Americans PROPN NNPS
# $ SYM $
# 11,000 NUM CD
# per ADP IN
# household NOUN NN
# , PUNCT ,
# and CCONJ CC
# end VERB VB
# Democrats PROPN NNPS
# ' PART POS
# regulatory ADJ JJ
# onslaught NOUN NN
# that PRON WDT
# disproportionately ADV RB
# harms VERB VBZ
# low- ADJ JJ
# and CCONJ CC
# middle ADJ JJ
# - PUNCT HYPH
# income NOUN NN
# households NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Stop VERB VB
# Illegal PROPN NNP
# Immigration PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# secure VERB VB
# the DET DT
# Border PROPN NNP
# , PUNCT ,
# deport VERB VB
# Illegal PROPN NNP
# Aliens PROPN NNP
# , PUNCT ,
# and CCONJ CC
# reverse VERB VB
# the DET DT
# Democrats PROPN NNPS
# ' PART POS
# Open PROPN NNP
# Borders PROPN NNPS
# Policies PROPN NNPS
# that PRON WDT
# have AUX VBP
# driven VERB VBN
# up ADP RP
# the DET DT
# cost NOUN NN
# of ADP IN
# Housing PROPN NNP
# , PUNCT ,
# Education PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Healthcare PROPN NNP
# for ADP IN
# American ADJ JJ
# families NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Restore VERB VB
# Peace PROPN NNP
# through ADP IN
# Strength PROPN NNP
#
#
#  SPACE _SP
# War PROPN NNP
# breeds VERB VBZ
# Inflation NOUN NN
# while SCONJ IN
# geopolitical ADJ JJ
# stability NOUN NN
# brings VERB VBZ
# price NOUN NN
# stability NOUN NN
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# end VERB VB
# the DET DT
# global ADJ JJ
# chaos NOUN NN
# and CCONJ CC
# restore VERB VB
# Peace NOUN NN
# through ADP IN
# Strength PROPN NNP
# , PUNCT ,
# reducing VERB VBG
# geopolitical ADJ JJ
# risks NOUN NNS
# and CCONJ CC
# lowering VERB VBG
# commodity NOUN NN
# prices NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER NOUN NN
# TWO NUM CD
# : PUNCT :
# SEAL VERB VB
# THE DET DT
# BORDER PROPN NNP
# , PUNCT ,
# AND CCONJ CC
# STOP VERB VB
# THE DET DT
# MIGRANT NOUN NNS
# INVASION NOUN NN
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# Republicans NOUN NNS
# offer VERB VBP
# an DET DT
# aggressive ADJ JJ
# plan NOUN NN
# to PART TO
# stop VERB VB
# the DET DT
# open ADJ JJ
# - PUNCT HYPH
# border NOUN NN
# policies NOUN NNS
# that PRON WDT
# have AUX VBP
# opened VERB VBN
# the DET DT
# floodgates NOUN NNS
# to ADP IN
# a DET DT
# tidal ADJ JJ
# wave NOUN NN
# of ADP IN
# illegal ADJ JJ
# Aliens PROPN NNP
# , PUNCT ,
# deadly ADJ JJ
# drugs NOUN NNS
# , PUNCT ,
# and CCONJ CC
# Migrant PROPN NNP
# Crime PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# end VERB VB
# the DET DT
# Invasion PROPN NNP
# at ADP IN
# the DET DT
# Southern PROPN NNP
# Border PROPN NNP
# , PUNCT ,
# restore VERB VB
# Law PROPN NNP
# and CCONJ CC
# Order PROPN NNP
# , PUNCT ,
# protect VERB VB
# American PROPN NNP
# Sovereignty PROPN NNP
# , PUNCT ,
# and CCONJ CC
# deliver VERB VB
# a DET DT
# Safe ADJ JJ
# and CCONJ CC
# Prosperous ADJ JJ
# Future PROPN NNP
# for ADP IN
# all DET DT
# Americans PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Secure VERB VB
# the DET DT
# Border PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# restore VERB VB
# every DET DT
# Border PROPN NNP
# Policy PROPN NNP
# of ADP IN
# the DET DT
# Trump PROPN NNP
# administration NOUN NN
# and CCONJ CC
# halt VERB VB
# all DET DT
# releases NOUN NNS
# of ADP IN
# Illegal ADJ JJ
# Aliens PROPN NNP
# into ADP IN
# the DET DT
# interior NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# complete VERB VB
# the DET DT
# Border PROPN NNP
# Wall PROPN NNP
# , PUNCT ,
# shift VERB VBP
# massive ADJ JJ
# portions NOUN NNS
# of ADP IN
# Federal PROPN NNP
# Law PROPN NNP
# Enforcement PROPN NNP
# to ADP IN
# Immigration PROPN NNP
# Enforcement PROPN NNP
# , PUNCT ,
# and CCONJ CC
# use VERB VB
# advanced ADJ JJ
# technology NOUN NN
# to PART TO
# monitor VERB VB
# and CCONJ CC
# secure VERB VB
# the DET DT
# Border PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# use VERB VB
# all DET DT
# resources NOUN NNS
# needed VERB VBN
# to PART TO
# stop VERB VB
# the DET DT
# Invasion PROPN NNP
# — PUNCT :
# including VERB VBG
# moving VERB VBG
# thousands NOUN NNS
# of ADP IN
# Troops PROPN NNPS
# currently ADV RB
# stationed VERB VBD
# overseas ADV RB
# to ADP IN
# our PRON PRP$
# own ADJ JJ
# Southern PROPN NNP
# Border PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# deploy VERB VB
# the DET DT
# U.S. PROPN NNP
# Navy PROPN NNP
# to PART TO
# impose VERB VB
# a DET DT
# full ADJ JJ
# Fentanyl PROPN NNP
# Blockade PROPN NNP
# on ADP IN
# the DET DT
# waters NOUN NNS
# of ADP IN
# our PRON PRP$
# Region NOUN NN
# — PUNCT :
# boarding NOUN NN
# and CCONJ CC
# inspecting VERB VBG
# ships NOUN NNS
# to PART TO
# look VERB VB
# for ADP IN
# fentanyl ADJ JJ
# and CCONJ CC
# fentanyl ADJ JJ
# precursors NOUN NNS
# . PUNCT .
# Before SCONJ IN
# we PRON PRP
# defend VERB VBP
# the DET DT
# Borders PROPN NNP
# of ADP IN
# Foreign PROPN NNP
# Countries PROPN NNPS
# , PUNCT ,
# we PRON PRP
# must AUX MD
# first ADV RB
# secure VERB VB
# the DET DT
# Border PROPN NNP
# of ADP IN
# our PRON PRP$
# Country PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Enforce PROPN NNP
# Immigration PROPN NNP
# Laws PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# strengthen VERB VB
# ICE NOUN NN
# , PUNCT ,
# increase VERB VB
# penalties NOUN NNS
# for ADP IN
# illegal ADJ JJ
# entry NOUN NN
# and CCONJ CC
# overstaying VERB VBG
# Visas PROPN NNP
# , PUNCT ,
# and CCONJ CC
# reinstate VERB VB
# " PUNCT ``
# Remain VERB VB
# in ADP IN
# Mexico PROPN NNP
# " PUNCT ''
# and CCONJ CC
# other ADJ JJ
# Policies PROPN NNPS
# that PRON WDT
# helped VERB VBD
# reduce VERB VB
# Illegal PROPN NNP
# Immigration PROPN NNP
# by ADP IN
# historic ADJ JJ
# lows NOUN NNS
# in ADP IN
# President PROPN NNP
# Trump PROPN NNP
# 's PART POS
# first ADJ JJ
# term NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# also ADV RB
# invoke VERB VB
# the DET DT
# Alien PROPN NNP
# Enemies PROPN NNPS
# Act PROPN NNP
# to PART TO
# remove VERB VB
# all PRON DT
# known VERB VBN
# or CCONJ CC
# suspected VERB VBN
# gang NOUN NN
# members NOUN NNS
# , PUNCT ,
# drug NOUN NN
# dealers NOUN NNS
# , PUNCT ,
# or CCONJ CC
# cartel NOUN NN
# members NOUN NNS
# from ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# , PUNCT ,
# ending VERB VBG
# the DET DT
# scourge NOUN NN
# of ADP IN
# Illegal PROPN NNP
# Alien PROPN NNP
# gang NOUN NN
# violence NOUN NN
# once ADV RB
# and CCONJ CC
# for ADP IN
# all PRON DT
# . PUNCT .
# We PRON PRP
# will AUX MD
# bring VERB VB
# back ADV RB
# the DET DT
# Travel PROPN NNP
# Ban PROPN NNP
# , PUNCT ,
# and CCONJ CC
# use VERB VB
# Title PROPN NNP
# 42 NUM CD
# to PART TO
# end VERB VB
# the DET DT
# child NOUN NN
# trafficking VERB VBG
# crisis NOUN NN
# by ADP IN
# returning VERB VBG
# all DET DT
# trafficked VERB VBN
# children NOUN NNS
# to ADP IN
# their PRON PRP$
# families NOUN NNS
# in ADP IN
# their PRON PRP$
# Home PROPN NNP
# Countries PROPN NNPS
# immediately ADV RB
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Begin VERB VB
# Largest PROPN NNP
# Deportation PROPN NNP
# Program PROPN NNP
# in ADP IN
# American PROPN NNP
# History PROPN NNP
#
#
#  SPACE _SP
# President PROPN NNP
# Trump PROPN NNP
# and CCONJ CC
# Republicans PROPN NNPS
# will AUX MD
# reverse VERB VB
# the DET DT
# Democrats PROPN NNPS
# ' PART POS
# destructive ADJ JJ
# Open PROPN NNP
# Borders PROPN NNPS
# Policies PROPN NNPS
# that PRON WDT
# have AUX VBP
# allowed VERB VBN
# criminal ADJ JJ
# gangs NOUN NNS
# and CCONJ CC
# Illegal ADJ JJ
# Aliens PROPN NNP
# from ADP IN
# around ADP IN
# the DET DT
# World PROPN NNP
# to PART TO
# roam VERB VB
# the DET DT
# United PROPN NNP
# States PROPN NNP
# without ADP IN
# consequences NOUN NNS
# . PUNCT .
# The DET DT
# Republican PROPN NNP
# Party PROPN NNP
# is AUX VBZ
# committed VERB VBN
# to ADP IN
# sending VERB VBG
# Illegal ADJ JJ
# Aliens PROPN NNP
# back ADV RB
# home ADV RB
# and CCONJ CC
# removing VERB VBG
# those PRON DT
# who PRON WP
# have AUX VBP
# violated VERB VBN
# our PRON PRP$
# Laws PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . PUNCT .
# Strict PROPN NNP
# Vetting PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# use VERB VB
# existing VERB VBG
# Federal PROPN NNP
# Law PROPN NNP
# to PART TO
# keep VERB VB
# foreign ADJ JJ
# Christian PROPN NNP
# - PUNCT HYPH
# hating VERB VBG
# Communists PROPN NNPS
# , PUNCT ,
# Marxists PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# Socialists PROPN NNPS
# out ADP IN
# of ADP IN
# America PROPN NNP
# . PUNCT .
# Those PRON DT
# who PRON WP
# join VERB VBP
# our PRON PRP$
# Country PROPN NNP
# must AUX MD
# love VERB VB
# our PRON PRP$
# Country PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# use VERB VB
# extreme ADJ JJ
# vetting NOUN NN
# to PART TO
# ensure VERB VB
# that SCONJ IN
# jihadists NOUN NNS
# and CCONJ CC
# jihadist PROPN NNP
# sympathizers NOUN NNS
# are AUX VBP
# not PART RB
# admitted VERB VBN
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Stop VERB VB
# Sanctuary PROPN NNP
# Cities PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# cut VERB VB
# federal ADJ JJ
# Funding PROPN NNP
# to ADP IN
# sanctuary ADJ JJ
# jurisdictions NOUN NNS
# that PRON WDT
# release VERB VBP
# dangerous ADJ JJ
# Illegal PROPN NNP
# Alien PROPN NNP
# criminals NOUN NNS
# onto ADP IN
# our PRON PRP$
# streets NOUN NNS
# , PUNCT ,
# rather ADV RB
# than ADP IN
# handing VERB VBG
# them PRON PRP
# over ADP RP
# to ADP IN
# ICE PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# require VERB VB
# local ADJ JJ
# cooperation NOUN NN
# with ADP IN
# Federal PROPN NNP
# Immigration PROPN NNP
# Enforcement PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . PUNCT .
# Ensure VERB VB
# Our PRON PRP$
# Legal PROPN NNP
# Immigration PROPN NNP
# System PROPN NNP
# Puts VERB VBZ
# American ADJ JJ
# Workers PROPN NNPS
# First PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# prioritize VERB VB
# Merit PROPN NNP
# - PUNCT HYPH
# based VERB VBN
# immigration NOUN NN
# , PUNCT ,
# ensuring VERB VBG
# those PRON DT
# admitted VERB VBN
# to ADP IN
# our PRON PRP$
# Country PROPN NNP
# contribute VERB VBP
# positively ADV RB
# to ADP IN
# our PRON PRP$
# Society PROPN NNP
# and CCONJ CC
# Economy PROPN NNP
# , PUNCT ,
# and CCONJ CC
# never ADV RB
# become VERB VB
# a DET DT
# drain NOUN NN
# on ADP IN
# Public PROPN NNP
# Resources PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# end VERB VB
# Chain PROPN NNP
# Migration PROPN NNP
# , PUNCT ,
# and CCONJ CC
# put VERB VBD
# American PROPN NNP
# Workers PROPN NNPS
# first ADV RB
# ! PUNCT .
#
#
#  SPACE _SP
# CHAPTER NOUN NN
# THREE NUM CD
# : PUNCT :
# BUILD VERB VB
# THE DET DT
# GREATEST PROPN NNP
# ECONOMY PROPN NNP
# IN ADP IN
# HISTORY NOUN NN
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# American PROPN NNP
# Workers PROPN NNPS
# are AUX VBP
# the DET DT
# most ADV RBS
# productive ADJ JJ
# , PUNCT ,
# talented ADJ JJ
# , PUNCT ,
# and CCONJ CC
# innovative ADJ JJ
# on ADP IN
# Earth PROPN NNP
# . PUNCT .
# The DET DT
# only ADJ JJ
# thing NOUN NN
# holding VERB VBG
# them PRON PRP
# back ADV RB
# is AUX VBZ
# the DET DT
# suffocating VERB VBG
# policies NOUN NNS
# of ADP IN
# the DET DT
# Democrat PROPN NNP
# Party PROPN NNP
# . PUNCT .
# Our PRON PRP$
# America PROPN NNP
# First PROPN NNP
# Economic PROPN NNP
# Agenda PROPN NNP
# rests VERB VBZ
# on ADP IN
# five NUM CD
# pillars NOUN NNS
# : PUNCT :
# Slashing VERB VBG
# Regulations NOUN NNS
# , PUNCT ,
# cutting VERB VBG
# Taxes PROPN NNP
# , PUNCT ,
# securing VERB VBG
# Fair PROPN NNP
# Trade PROPN NNP
# Deals NOUN NNS
# , PUNCT ,
# ensuring VERB VBG
# Reliable PROPN NNP
# and CCONJ CC
# Abundant PROPN NNP
# Low PROPN NNP
# Cost PROPN NNP
# Energy PROPN NNP
# , PUNCT ,
# and CCONJ CC
# championing VERB VBG
# Innovation PROPN NNP
# . PUNCT .
# Together ADV RB
# , PUNCT ,
# we PRON PRP
# will AUX MD
# restore VERB VB
# Economic PROPN NNP
# Prosperity PROPN NNP
# and CCONJ CC
# Opportunity PROPN NNP
# for ADP IN
# all DET DT
# Americans PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . X LS
# Cut PROPN NNP
# Regulations PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# slash VERB VB
# Regulations NOUN NNS
# that PRON WDT
# stifle VERB VBP
# Jobs PROPN NNP
# , PUNCT ,
# Freedom PROPN NNP
# , PUNCT ,
# Innovation PROPN NNP
# and CCONJ CC
# make VERB VB
# everything PRON NN
# more ADV RBR
# expensive ADJ JJ
# . PUNCT .
# We PRON PRP
# will AUX MD
# implement VERB VB
# Transparency PROPN NNP
# and CCONJ CC
# Common PROPN NNP
# Sense PROPN NNP
# in ADP IN
# rulemaking VERB VBG
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Make VERB VB
# Trump PROPN NNP
# Tax NOUN NN
# Cuts PROPN NNPS
# Permanent PROPN NNP
# and CCONJ CC
# No DET DT
# Tax NOUN NN
# on ADP IN
# Tips PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# make VERB VB
# permanent ADJ JJ
# the DET DT
# provisions NOUN NNS
# of ADP IN
# the DET DT
# Trump PROPN NNP
# Tax PROPN NNP
# Cuts PROPN NNPS
# and CCONJ CC
# Jobs PROPN NNP
# Act PROPN NNP
# that PRON WDT
# doubled VERB VBD
# the DET DT
# standard ADJ JJ
# deduction NOUN NN
# , PUNCT ,
# expanded VERB VBD
# the DET DT
# Child PROPN NNP
# Tax PROPN NNP
# Credit PROPN NNP
# , PUNCT ,
# and CCONJ CC
# spurred VERB VBD
# Economic PROPN NNP
# Growth PROPN NNP
# for ADP IN
# all DET DT
# Americans PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# eliminate VERB VB
# Taxes PROPN NNP
# on ADP IN
# Tips PROPN NNP
# for ADP IN
# millions NOUN NNS
# of ADP IN
# Restaurant PROPN NNP
# and CCONJ CC
# Hospitality PROPN NNP
# Workers PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# pursue VERB VB
# additional ADJ JJ
# Tax PROPN NNP
# Cuts PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Fair ADJ JJ
# and CCONJ CC
# Reciprocal PROPN NNP
# Trade PROPN NNP
# Deals NOUN NNS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# continue VERB VB
# forging VERB VBG
# an DET DT
# America PROPN NNP
# First PROPN NNP
# Trade PROPN NNP
# Policy PROPN NNP
# as SCONJ IN
# set VERB VBN
# forth ADV RB
# in ADP IN
# Chapter NOUN NN
# 5 NUM CD
# , PUNCT ,
# standing VERB VBG
# up ADP RP
# to ADP IN
# Countries PROPN NNPS
# that PRON WDT
# cheat VERB VBP
# and CCONJ CC
# prioritizing VERB VBG
# American PROPN NNP
# Producers PROPN NNPS
# over ADP IN
# Foreign PROPN NNP
# Outsourcers PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# bring VERB VB
# our PRON PRP$
# critical ADJ JJ
# Supply PROPN NNP
# Chains PROPN NNPS
# back ADV RB
# home ADV RB
# . PUNCT .
# President PROPN NNP
# Trump PROPN NNP
# turned VERB VBD
# American PROPN NNP
# Trade PROPN NNP
# Policy PROPN NNP
# around ADV RB
# , PUNCT ,
# protecting VERB VBG
# U.S. PROPN NNP
# Producers PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# renegotiating VERB VBG
# failed VERB VBN
# agreements NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Reliable ADJ JJ
# and CCONJ CC
# Abundant PROPN NNP
# Low PROPN NNP
# Cost PROPN NNP
# Energy PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# increase VERB VB
# Energy PROPN NNP
# Production PROPN NNP
# across ADP IN
# the DET DT
# board NOUN NN
# , PUNCT ,
# streamline VERB VB
# permitting NOUN NN
# , PUNCT ,
# and CCONJ CC
# end VERB VB
# market NOUN NN
# - PUNCT HYPH
# distorting VERB VBG
# restrictions NOUN NNS
# on ADP IN
# Oil PROPN NNP
# , PUNCT ,
# Natural PROPN NNP
# Gas PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Coal PROPN NNP
# . PUNCT .
# The DET DT
# Republican PROPN NNP
# Party PROPN NNP
# will AUX MD
# once ADV RB
# again ADV RB
# make VERB VB
# America PROPN NNP
# Energy PROPN NNP
# Independent PROPN NNP
# , PUNCT ,
# and CCONJ CC
# then ADV RB
# Energy PROPN NNP
# Dominant PROPN NNP
# , PUNCT ,
# lowering VERB VBG
# Energy NOUN NN
# prices NOUN NNS
# even ADV RB
# below ADP IN
# the DET DT
# record NOUN NN
# lows NOUN NNS
# achieved VERB VBN
# during ADP IN
# President PROPN NNP
# Trump PROPN NNP
# 's PART POS
# first ADJ JJ
# term NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Champion PROPN NNP
# Innovation PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# pave VERB VB
# the DET DT
# way NOUN NN
# for ADP IN
# future ADJ JJ
# Economic PROPN NNP
# Greatness PROPN NNP
# by ADP IN
# leading VERB VBG
# the DET DT
# World PROPN NNP
# in ADP IN
# Emerging PROPN NNP
# Industries PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# Crypto PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# end VERB VB
# Democrats PROPN NNPS
# ' PART POS
# unlawful ADJ JJ
# and CCONJ CC
# unAmerican ADJ JJ
# Crypto PROPN NNP
# crackdown NOUN NN
# and CCONJ CC
# oppose VERB VB
# the DET DT
# creation NOUN NN
# of ADP IN
# a DET DT
# Central PROPN NNP
# Bank PROPN NNP
# Digital PROPN NNP
# Currency PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# defend VERB VB
# the DET DT
# right NOUN NN
# to ADP IN
# mine PRON PRP
# Bitcoin PROPN NNP
# , PUNCT ,
# and CCONJ CC
# ensure VERB VB
# every DET DT
# American PROPN NNP
# has VERB VBZ
# the DET DT
# right NOUN NN
# to ADP IN
# self NOUN NN
# - PUNCT HYPH
# custody NOUN NN
# of ADP IN
# their PRON PRP$
# Digital PROPN NNP
# Assets PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# transact VERB VB
# free ADJ JJ
# from ADP IN
# Government PROPN NNP
# Surveillance PROPN NNP
# and CCONJ CC
# Control PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# Artificial PROPN NNP
# Intelligence PROPN NNP
# ( PUNCT -LRB-
# AI PROPN NNP
# ) PUNCT -RRB-
#
#
#  SPACE _SP
# We PRON PRP
# will AUX MD
# repeal VERB VB
# Joe PROPN NNP
# Biden PROPN NNP
# 's PART POS
# dangerous ADJ JJ
# Executive PROPN NNP
# Order PROPN NNP
# that PRON WDT
# hinders VERB VBZ
# AI PROPN NNP
# Innovation PROPN NNP
# , PUNCT ,
# and CCONJ CC
# imposes VERB VBZ
# Radical PROPN NNP
# Leftwing PROPN NNP
# ideas NOUN NNS
# on ADP IN
# the DET DT
# development NOUN NN
# of ADP IN
# this DET DT
# technology NOUN NN
# . PUNCT .
# In ADP IN
# its PRON PRP$
# place NOUN NN
# , PUNCT ,
# Republicans PROPN NNPS
# support VERB VBP
# AI PROPN NNP
# Development PROPN NNP
# rooted VERB VBN
# in ADP IN
# Free PROPN NNP
# Speech PROPN NNP
# and CCONJ CC
# Human PROPN NNP
# Flourishing PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# Expanding VERB VBG
# Freedom PROPN NNP
# , PUNCT ,
# Prosperity PROPN NNP
# and CCONJ CC
# Safety PROPN NNP
# in ADP IN
# Space PROPN NNP
#
#
#  SPACE _SP
# Under ADP IN
# Republican ADJ JJ
# Leadership PROPN NNP
# , PUNCT ,
# the DET DT
# United PROPN NNP
# States PROPN NNP
# will AUX MD
# create VERB VB
# a DET DT
# robust ADJ JJ
# Manufacturing PROPN NNP
# Industry PROPN NNP
# in ADP IN
# Near PROPN NNP
# Earth PROPN NNP
# Orbit PROPN NNP
# , PUNCT ,
# send VERB VBP
# American PROPN NNP
# Astronauts PROPN NNPS
# back ADV RB
# to ADP IN
# the DET DT
# Moon PROPN NNP
# , PUNCT ,
# and CCONJ CC
# onward ADV RB
# to ADP IN
# Mars PROPN NNP
# , PUNCT ,
# and CCONJ CC
# enhance VERB VB
# partnerships NOUN NNS
# with ADP IN
# the DET DT
# rapidly ADV RB
# expanding VERB VBG
# Commercial PROPN NNP
# Space PROPN NNP
# sector NOUN NN
# to PART TO
# revolutionize VERB VB
# our PRON PRP$
# ability NOUN NN
# to PART TO
# access VERB VB
# , PUNCT ,
# live VERB VBP
# in ADP IN
# , PUNCT ,
# and CCONJ CC
# develop VERB VB
# assets NOUN NNS
# in ADP IN
# Space PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER PROPN NNP
# FOUR PROPN NNP
# : PUNCT :
# BRING VERB VB
# BACK ADP RP
# THE DET DT
# AMERICAN PROPN NNP
# DREAM PROPN NNP
# AND CCONJ CC
# MAKE VERB VB
# IT PRON PRP
# AFFORDABLE VERB VBZ
# AGAIN ADV RB
# FOR ADP IN
# FAMILIES NOUN NNS
# , PUNCT ,
# YOUNG ADJ JJ
# PEOPLE PROPN NNP
# , PUNCT ,
# AND CCONJ CC
# EVERYONE VERB VBP
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# Republicans NOUN NNS
# offer VERB VBP
# a DET DT
# plan NOUN NN
# to PART TO
# make VERB VB
# the DET DT
# American ADJ JJ
# Dream PROPN NNP
# affordable ADJ JJ
# again ADV RB
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# reducing VERB VBG
# Housing PROPN NNP
# , PUNCT ,
# Education PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Healthcare PROPN NNP
# costs NOUN NNS
# , PUNCT ,
# while SCONJ IN
# lowering VERB VBG
# everyday ADJ JJ
# expenses NOUN NNS
# , PUNCT ,
# and CCONJ CC
# increasing VERB VBG
# opportunities NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Housing PROPN NNP
# Affordability NOUN NN
#
#
#  SPACE _SP
# To PART TO
# help VERB VB
# new ADJ JJ
# home NOUN NN
# buyers NOUN NNS
# , PUNCT ,
# Republicans PROPN NNPS
# will AUX MD
# reduce VERB VB
# mortgage NOUN NN
# rates NOUN NNS
# by ADP IN
# slashing VERB VBG
# Inflation PROPN NNP
# , PUNCT ,
# open ADJ JJ
# limited ADJ JJ
# portions NOUN NNS
# of ADP IN
# Federal PROPN NNP
# Lands PROPN NNPS
# to PART TO
# allow VERB VB
# for ADP IN
# new ADJ JJ
# home NOUN NN
# construction NOUN NN
# , PUNCT ,
# promote VERB VB
# homeownership NOUN NN
# through ADP IN
# Tax PROPN NNP
# Incentives PROPN NNPS
# and CCONJ CC
# support NOUN NN
# for ADP IN
# first ADJ JJ
# - PUNCT HYPH
# time NOUN NN
# buyers NOUN NNS
# , PUNCT ,
# and CCONJ CC
# cut VERB VB
# unnecessary ADJ JJ
# Regulations PROPN NNPS
# that PRON WDT
# raise VERB VBP
# housing NOUN NN
# costs NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . PUNCT .
# Accessible ADJ JJ
# Higher ADJ JJR
# Education NOUN NN
#
#
#  SPACE _SP
# To PART TO
# reduce VERB VB
# the DET DT
# cost NOUN NN
# of ADP IN
# Higher ADJ JJR
# Education PROPN NNP
# , PUNCT ,
# Republicans PROPN NNPS
# will AUX MD
# support VERB VB
# the DET DT
# creation NOUN NN
# of ADP IN
# additional ADJ JJ
# , PUNCT ,
# drastically ADV RB
# more ADV RBR
# affordable ADJ JJ
# alternatives NOUN NNS
# to ADP IN
# a DET DT
# traditional ADJ JJ
# four NUM CD
# - PUNCT HYPH
# year NOUN NN
# College PROPN NNP
# degree NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Affordable PROPN NNP
# Healthcare PROPN NNP
#
#
#  SPACE _SP
# Healthcare PROPN NNP
# and CCONJ CC
# prescription NOUN NN
# drug NOUN NN
# costs NOUN NNS
# are AUX VBP
# out ADP IN
# of ADP IN
# control NOUN NN
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# increase VERB VB
# Transparency PROPN NNP
# , PUNCT ,
# promote VERB VB
# Choice PROPN NNP
# and CCONJ CC
# Competition NOUN NN
# , PUNCT ,
# and CCONJ CC
# expand VERB VB
# access NOUN NN
# to ADP IN
# new ADJ JJ
# Affordable PROPN NNP
# Healthcare PROPN NNP
# and CCONJ CC
# prescription NOUN NN
# drug NOUN NN
# options NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# protect VERB VB
# Medicare PROPN NNP
# , PUNCT ,
# and CCONJ CC
# ensure VERB VB
# Seniors NOUN NNS
# receive VERB VBP
# the DET DT
# care NOUN NN
# they PRON PRP
# need VERB VBP
# without ADP IN
# being AUX VBG
# burdened VERB VBN
# by ADP IN
# excessive ADJ JJ
# costs NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Lower ADJ JJR
# Everyday PROPN NNP
# Costs NOUN NNS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# reduce VERB VB
# the DET DT
# Regulatory ADJ JJ
# burden NOUN NN
# , PUNCT ,
# lower ADJ JJR
# Energy NOUN NN
# costs NOUN NNS
# , PUNCT ,
# and CCONJ CC
# promote VERB VB
# Economic PROPN NNP
# Policies PROPN NNPS
# that PRON WDT
# drive VERB VBP
# down ADP RP
# the DET DT
# cost NOUN NN
# of ADP IN
# living NOUN NN
# and CCONJ CC
# prices NOUN NNS
# for ADP IN
# everyday ADJ JJ
# goods NOUN NNS
# and CCONJ CC
# services NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER NOUN NN
# FIVE NUM CD
# : PUNCT :
# PROTECT VERB VB
# AMERICAN PROPN NNP
# WORKERS NOUN NNS
# AND CCONJ CC
# FARMERS NOUN NNS
# FROM ADP IN
# UNFAIR ADJ JJ
# TRADE PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# The DET DT
# Republican PROPN NNP
# Party PROPN NNP
# stands VERB VBZ
# for ADP IN
# a DET DT
# patriotic ADJ JJ
# " PUNCT ``
# America PROPN NNP
# First PROPN NNP
# " PUNCT ``
# Economic PROPN NNP
# Policy PROPN NNP
# . PUNCT .
# Republicans PROPN NNPS
# offer VERB VBP
# a DET DT
# robust ADJ JJ
# plan NOUN NN
# to PART TO
# protect VERB VB
# American PROPN NNP
# Workers PROPN NNPS
# , PUNCT ,
# Farmers PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Industries PROPN NNPS
# from ADP IN
# unfair ADJ JJ
# Foreign PROPN NNP
# Competition PROPN NNP
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# rebalancing NOUN NN
# Trade PROPN NNP
# , PUNCT ,
# securing VERB VBG
# Strategic PROPN NNP
# Independence PROPN NNP
# , PUNCT ,
# and CCONJ CC
# revitalizing VERB VBG
# Manufacturing PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# prioritize VERB VB
# Domestic PROPN NNP
# Production PROPN NNP
# , PUNCT ,
# and CCONJ CC
# ensure VERB VB
# National PROPN NNP
# Independence PROPN NNP
# in ADP IN
# essential ADJ JJ
# goods NOUN NNS
# and CCONJ CC
# services NOUN NNS
# . PUNCT .
# Together ADV RB
# , PUNCT ,
# we PRON PRP
# will AUX MD
# build VERB VB
# a DET DT
# Strong ADJ JJ
# , PUNCT ,
# Self NOUN NN
# - PUNCT HYPH
# reliant ADJ JJ
# , PUNCT ,
# and CCONJ CC
# Prosperous PROPN NNP
# America PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Rebalance PROPN NNP
# Trade PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Trade PROPN NNP
# deficit NOUN NN
# in ADP IN
# goods NOUN NNS
# has AUX VBZ
# grown VERB VBN
# to ADP IN
# over ADP IN
# $ SYM $
# 1 NUM CD
# Trillion NUM CD
# Dollars NOUN NNS
# a DET DT
# year NOUN NN
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# support VERB VB
# baseline VERB VB
# Tariffs NOUN NNS
# on ADP IN
# Foreign PROPN NNP
# - PUNCT HYPH
# made VERB VBN
# goods NOUN NNS
# , PUNCT ,
# pass VERB VB
# the DET DT
# Trump PROPN NNP
# Reciprocal PROPN NNP
# Trade PROPN NNP
# Act PROPN NNP
# , PUNCT ,
# and CCONJ CC
# respond VERB VB
# to ADP IN
# unfair ADJ JJ
# Trading NOUN NN
# practices NOUN NNS
# . PUNCT .
# As SCONJ IN
# Tariffs NOUN NNS
# on ADP IN
# Foreign PROPN NNP
# Producers PROPN NNPS
# go VERB VBP
# up ADP RP
# , PUNCT ,
# Taxes NOUN NNS
# on ADP IN
# American ADJ JJ
# Workers PROPN NNPS
# , PUNCT ,
# Families PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Businesses NOUN NNS
# can AUX MD
# come VERB VB
# down ADP RP
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Secure VERB VB
# Strategic ADJ JJ
# Independence NOUN NN
# from ADP IN
# China PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# revoke VERB VB
# China PROPN NNP
# 's PART POS
# Most ADV RBS
# Favored ADJ JJ
# Nation NOUN NN
# status NOUN NN
# , PUNCT ,
# phase VERB VB
# out ADP RP
# imports NOUN NNS
# of ADP IN
# essential ADJ JJ
# goods NOUN NNS
# , PUNCT ,
# and CCONJ CC
# stop VERB VB
# China PROPN NNP
# from ADP IN
# buying VERB VBG
# American PROPN NNP
# Real PROPN NNP
# Estate PROPN NNP
# and CCONJ CC
# Industries PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Save VERB VB
# the DET DT
# American PROPN NNP
# Auto PROPN NNP
# Industry PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# revive VERB VB
# the DET DT
# U.S. PROPN NNP
# Auto PROPN NNP
# Industry PROPN NNP
# by ADP IN
# reversing VERB VBG
# harmful ADJ JJ
# Regulations NOUN NNS
# , PUNCT ,
# canceling VERB VBG
# Biden PROPN NNP
# 's PART POS
# Electric PROPN NNP
# Vehicle PROPN NNP
# and CCONJ CC
# other ADJ JJ
# Mandates PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# preventing VERB VBG
# the DET DT
# importation NOUN NN
# of ADP IN
# Chinese ADJ JJ
# vehicles NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Bring VERB VB
# Home PROPN NNP
# Critical PROPN NNP
# Supply PROPN NNP
# Chains PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# bring VERB VB
# critical ADJ JJ
# Supply PROPN NNP
# Chains PROPN NNPS
# back ADV RB
# to ADP IN
# the DET DT
# U.S. PROPN NNP
# , PUNCT ,
# ensuring VERB VBG
# National PROPN NNP
# Security PROPN NNP
# and CCONJ CC
# Economic PROPN NNP
# Stability PROPN NNP
# , PUNCT ,
# while SCONJ IN
# also ADV RB
# creating VERB VBG
# Jobs PROPN NNP
# and CCONJ CC
# raising VERB VBG
# Wages PROPN NNPS
# for ADP IN
# American PROPN NNP
# Workers PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Buy VERB VB
# American PROPN NNP
# and CCONJ CC
# Hire PROPN NNP
# American PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# strengthen VERB VB
# Buy PROPN NNP
# American PROPN NNP
# and CCONJ CC
# Hire PROPN NNP
# American PROPN NNP
# Policies PROPN NNP
# , PUNCT ,
# banning VERB VBG
# companies NOUN NNS
# that PRON WDT
# outsource VERB VBP
# jobs NOUN NNS
# from ADP IN
# doing VERB VBG
# business NOUN NN
# with ADP IN
# the DET DT
# Federal PROPN NNP
# Government PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . X LS
# Become VERB VB
# the DET DT
# Manufacturing PROPN NNP
# Superpower NOUN NN
#
#
#  SPACE _SP
# By ADP IN
# protecting VERB VBG
# American PROPN NNP
# Workers PROPN NNPS
# from ADP IN
# unfair ADJ JJ
# Foreign PROPN NNP
# Competition PROPN NNP
# and CCONJ CC
# unleashing VERB VBG
# American PROPN NNP
# Energy PROPN NNP
# , PUNCT ,
# Republicans PROPN NNPS
# will AUX MD
# restore VERB VB
# American PROPN NNP
# Manufacturing PROPN NNP
# , PUNCT ,
# creating VERB VBG
# Jobs PROPN NNP
# , PUNCT ,
# Wealth PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Investment PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER NOUN NN
# SIX PROPN NNP
# : PUNCT :
# PROTECT NOUN NN
# SENIORS PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# President PROPN NNP
# Trump PROPN NNP
# has AUX VBZ
# made VERB VBN
# absolutely ADV RB
# clear ADJ JJ
# that SCONJ IN
# he PRON PRP
# will AUX MD
# not PART RB
# cut VERB VB
# one NUM CD
# penny NOUN NN
# from ADP IN
# Medicare PROPN NNP
# or CCONJ CC
# Social PROPN NNP
# Security PROPN NNP
# . PUNCT .
# American ADJ JJ
# Citizens PROPN NNPS
# work VERB VBP
# hard ADV RB
# their PRON PRP$
# whole ADJ JJ
# lives NOUN NNS
# , PUNCT ,
# contributing VERB VBG
# to ADP IN
# Social PROPN NNP
# Security PROPN NNP
# and CCONJ CC
# Medicare PROPN NNP
# . PUNCT .
# These DET DT
# programs NOUN NNS
# are AUX VBP
# promises NOUN NNS
# to ADP IN
# our PRON PRP$
# Seniors NOUN NNS
# , PUNCT ,
# ensuring VERB VBG
# they PRON PRP
# can AUX MD
# live VERB VB
# their PRON PRP$
# golden ADJ JJ
# years NOUN NNS
# with ADP IN
# dignity NOUN NN
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# protect VERB VB
# these DET DT
# vital ADJ JJ
# programs NOUN NNS
# and CCONJ CC
# ensure VERB VB
# Economic PROPN NNP
# Stability PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# work VERB VB
# with ADP IN
# our PRON PRP$
# Great PROPN NNP
# Seniors PROPN NNPS
# , PUNCT ,
# in ADP IN
# order NOUN NN
# to PART TO
# allow VERB VB
# them PRON PRP
# to PART TO
# be AUX VB
# active ADJ JJ
# and CCONJ CC
# healthy ADJ JJ
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# safeguarding VERB VBG
# the DET DT
# future NOUN NN
# for ADP IN
# our PRON PRP$
# Seniors PROPN NNPS
# and CCONJ CC
# all DET DT
# American ADJ JJ
# families NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Protect VERB VB
# Social PROPN NNP
# Security PROPN NNP
#
#
#  SPACE _SP
# Social PROPN NNP
# Security PROPN NNP
# is AUX VBZ
# a DET DT
# lifeline NOUN NN
# for ADP IN
# millions NOUN NNS
# of ADP IN
# Retirees NOUN NNS
# , PUNCT ,
# yet CCONJ CC
# corrupt ADJ JJ
# politicians NOUN NNS
# have AUX VBP
# robbed VERB VBN
# Social PROPN NNP
# Security PROPN NNP
# to PART TO
# fund VERB VB
# their PRON PRP$
# pet ADJ JJ
# projects NOUN NNS
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# restore VERB VB
# Economic PROPN NNP
# Stability PROPN NNP
# to PART TO
# ensure VERB VB
# the DET DT
# long ADJ JJ
# - PUNCT HYPH
# term NOUN NN
# sustainability NOUN NN
# of ADP IN
# Social PROPN NNP
# Security PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . PUNCT .
# Strengthen VERB VB
# Medicare PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# protect VERB VB
# Medicare PROPN NNP
# 's PART POS
# finances NOUN NNS
# from ADP IN
# being AUX VBG
# financially ADV RB
# crushed VERB VBN
# by ADP IN
# the DET DT
# Democrat PROPN NNP
# plan NOUN NN
# to PART TO
# add VERB VB
# tens NOUN NNS
# of ADP IN
# millions NOUN NNS
# of ADP IN
# new ADJ JJ
# illegal ADJ JJ
# immigrants NOUN NNS
# to ADP IN
# the DET DT
# rolls NOUN NNS
# of ADP IN
# Medicare PROPN NNP
# . PUNCT .
# We PRON PRP
# vow VERB VBP
# to PART TO
# strengthen VERB VB
# Medicare PROPN NNP
# for ADP IN
# future ADJ JJ
# generations NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Support VERB VB
# Active PROPN NNP
# and CCONJ CC
# Healthy PROPN NNP
# Living PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# support VERB VB
# increased VERB VBN
# focus NOUN NN
# on ADP IN
# Chronic PROPN NNP
# Disease PROPN NNP
# prevention NOUN NN
# and CCONJ CC
# management NOUN NN
# , PUNCT ,
# Long ADJ JJ
# - PUNCT HYPH
# Term PROPN NNP
# Care PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Benefit NOUN NN
# flexibility NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# expand VERB VB
# access NOUN NN
# to ADP IN
# Primary PROPN NNP
# Care PROPN NNP
# and CCONJ CC
# support VERB VB
# Policies PROPN NNPS
# that PRON WDT
# help VERB VBP
# Seniors NOUN NNS
# remain VERB VBP
# in ADP IN
# their PRON PRP$
# homes NOUN NNS
# and CCONJ CC
# maintain VERB VB
# Financial PROPN NNP
# Security PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . PUNCT .
# Protect VERB VB
# Care PROPN NNP
# at ADP IN
# Home PROPN NNP
# for ADP IN
# the DET DT
# Elderly PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# shift VERB VB
# resources NOUN NNS
# back ADV RB
# to ADP IN
# at ADP IN
# - PUNCT HYPH
# home NOUN NN
# Senior PROPN NNP
# Care PROPN NNP
# , PUNCT ,
# overturn NOUN NN
# disincentives NOUN NNS
# that PRON WDT
# lead VERB VBP
# to ADP IN
# Care PROPN NNP
# Worker PROPN NNP
# shortages NOUN NNS
# , PUNCT ,
# and CCONJ CC
# support NOUN NN
# unpaid VERB VBD
# Family PROPN NNP
# Caregivers PROPN NNPS
# through ADP IN
# Tax NOUN NN
# Credits PROPN NNP
# and CCONJ CC
# reduced VERB VBN
# red ADJ JJ
# tape NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Protect VERB VB
# Economic PROPN NNP
# Foundations PROPN NNP
# for ADP IN
# Supporting VERB VBG
# Seniors NOUN NNS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# tackle VERB VB
# Inflation NOUN NN
# , PUNCT ,
# unleash VERB VBP
# American PROPN NNP
# Energy PROPN NNP
# , PUNCT ,
# restore VERB VB
# Economic PROPN NNP
# Growth PROPN NNP
# , PUNCT ,
# and CCONJ CC
# secure VERB VB
# our PRON PRP$
# Borders PROPN NNPS
# to PART TO
# preserve VERB VB
# Social PROPN NNP
# Security PROPN NNP
# and CCONJ CC
# Medicare PROPN NNP
# funding NOUN NN
# for ADP IN
# the DET DT
# next ADJ JJ
# Generation NOUN NN
# and CCONJ CC
# beyond ADV RB
# . PUNCT .
# We PRON PRP
# will AUX MD
# ensure VERB VB
# these DET DT
# programs NOUN NNS
# remain VERB VBP
# solvent ADV RB
# long ADV RB
# into ADP IN
# the DET DT
# future NOUN NN
# by ADP IN
# reversing VERB VBG
# harmful ADJ JJ
# Democrat PROPN NNP
# policies NOUN NNS
# and CCONJ CC
# unleashing VERB VBG
# a DET DT
# new ADJ JJ
# Economic PROPN NNP
# Boom PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER PROPN NNP
# SEVEN PROPN NNP
# : PUNCT :
# CULTIVATE VERB VB
# GREAT PROPN NNP
# K-12 NOUN NN
# SCHOOLS PROPN NNP
# LEADING VERB VBG
# TO ADP IN
# GREAT PROPN NNP
# JOBS PROPN NNP
# AND CCONJ CC
# GREAT ADJ JJ
# LIVES PROPN NNP
# FOR ADP IN
# YOUNG ADJ JJ
# PEOPLE NOUN NNS
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# Republicans NOUN NNS
# offer VERB VBP
# a DET DT
# plan NOUN NN
# to PART TO
# cultivate VERB VB
# great ADJ JJ
# K-12 NOUN NNS
# schools NOUN NNS
# , PUNCT ,
# ensure VERB VB
# safe ADJ JJ
# learning VERB VBG
# environments NOUN NNS
# free ADJ JJ
# from ADP IN
# political ADJ JJ
# meddling NOUN NN
# , PUNCT ,
# and CCONJ CC
# restore VERB VB
# Parental PROPN NNP
# Rights PROPN NNPS
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# an DET DT
# Education PROPN NNP
# System PROPN NNP
# that PRON WDT
# empowers VERB VBZ
# students NOUN NNS
# , PUNCT ,
# supports VERB VBZ
# families NOUN NNS
# , PUNCT ,
# and CCONJ CC
# promotes VERB VBZ
# American ADJ JJ
# Values PROPN NNPS
# . PUNCT .
# Our PRON PRP$
# Education PROPN NNP
# System PROPN NNP
# must AUX MD
# prepare VERB VB
# students NOUN NNS
# for ADP IN
# successful ADJ JJ
# lives NOUN NNS
# and CCONJ CC
# well ADV RB
# - PUNCT HYPH
# paying VERB VBG
# jobs NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Great PROPN NNP
# Principals PROPN NNPS
# and CCONJ CC
# Great PROPN NNP
# Teachers PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# support VERB VB
# schools NOUN NNS
# that PRON WDT
# focus VERB VBP
# on ADP IN
# Excellence PROPN NNP
# and CCONJ CC
# Parental PROPN NNP
# Rights PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# support VERB VB
# ending VERB VBG
# Teacher NOUN NN
# Tenure PROPN NNP
# , PUNCT ,
# adopting VERB VBG
# Merit PROPN NNP
# pay NOUN NN
# , PUNCT ,
# and CCONJ CC
# allowing VERB VBG
# various ADJ JJ
# publicly ADV RB
# supported VERB VBN
# Educational ADJ JJ
# models NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Universal PROPN NNP
# School PROPN NNP
# Choice PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# believe VERB VBP
# families NOUN NNS
# should AUX MD
# be AUX VB
# empowered VERB VBN
# to PART TO
# choose VERB VB
# the DET DT
# best ADJ JJS
# Education NOUN NN
# for ADP IN
# their PRON PRP$
# children NOUN NNS
# . PUNCT .
# We PRON PRP
# support VERB VBP
# Universal PROPN NNP
# School PROPN NNP
# Choice PROPN NNP
# in ADP IN
# every DET DT
# State PROPN NNP
# in ADP IN
# America PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# expand VERB VB
# 529 NUM CD
# Education PROPN NNP
# Savings PROPN NNPS
# Accounts PROPN NNPS
# and CCONJ CC
# support VERB VB
# Homeschooling PROPN NNP
# Families PROPN NNP
# equally ADV RB
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Prepare VERB VB
# Students NOUN NNS
# for ADP IN
# Jobs PROPN NNP
# and CCONJ CC
# Careers PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# emphasize VERB VB
# Education PROPN NNP
# to PART TO
# prepare VERB VB
# students NOUN NNS
# for ADP IN
# great ADJ JJ
# jobs NOUN NNS
# and CCONJ CC
# careers NOUN NNS
# , PUNCT ,
# supporting VERB VBG
# project NOUN NN
# - PUNCT HYPH
# based VERB VBN
# learning NOUN NN
# and CCONJ CC
# schools NOUN NNS
# that PRON WDT
# offer VERB VBP
# meaningful ADJ JJ
# work NOUN NN
# experience NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# expose VERB VB
# politicized ADJ JJ
# education NOUN NN
# models NOUN NNS
# and CCONJ CC
# fund NOUN NN
# proven VERB VBN
# career NOUN NN
# training NOUN NN
# programs NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Safe ADJ JJ
# , PUNCT ,
# Secure ADJ JJ
# , PUNCT ,
# and CCONJ CC
# Drug PROPN NNP
# - PUNCT HYPH
# Free PROPN NNP
# Schools PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# support VERB VB
# overhauling VERB VBG
# standards NOUN NNS
# on ADP IN
# school NOUN NN
# discipline NOUN NN
# , PUNCT ,
# advocate VERB VBP
# for ADP IN
# immediate ADJ JJ
# suspension NOUN NN
# of ADP IN
# violent ADJ JJ
# students NOUN NNS
# , PUNCT ,
# and CCONJ CC
# support VERB VB
# hardening VERB VBG
# schools NOUN NNS
# to PART TO
# help VERB VB
# keep VERB VB
# violence NOUN NN
# away ADV RB
# from ADP IN
# our PRON PRP$
# places NOUN NNS
# of ADP IN
# learning VERB VBG
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Restore PROPN NNP
# Parental PROPN NNP
# Rights PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# restore VERB VB
# Parental PROPN NNP
# Rights PROPN NNPS
# in ADP IN
# Education PROPN NNP
# , PUNCT ,
# and CCONJ CC
# enforce VERB VB
# our PRON PRP$
# Civil PROPN NNP
# Rights PROPN NNPS
# Laws PROPN NNPS
# to PART TO
# stop VERB VB
# schools NOUN NNS
# from ADP IN
# discriminating VERB VBG
# on ADP IN
# the DET DT
# basis NOUN NN
# of ADP IN
# Race PROPN NNP
# . PUNCT .
# We PRON PRP
# trust VERB VBP
# Parents NOUN NNS
# ! PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . PUNCT .
# Knowledge PROPN NNP
# and CCONJ CC
# Skills PROPN NNPS
# , PUNCT ,
# Not PART RB
# CRT PROPN NNP
# and CCONJ CC
# Gender PROPN NNP
# Indoctrination PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# ensure VERB VB
# children NOUN NNS
# are AUX VBP
# taught VERB VBN
# fundamentals NOUN NNS
# like ADP IN
# Reading PROPN NNP
# , PUNCT ,
# History NOUN NN
# , PUNCT ,
# Science PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Math PROPN NNP
# , PUNCT ,
# not PART RB
# Leftwing VERB VBG
# propaganda NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# defund VERB VB
# schools NOUN NNS
# that PRON WDT
# engage VERB VBP
# in ADP IN
# inappropriate ADJ JJ
# political ADJ JJ
# indoctrination NOUN NN
# of ADP IN
# our PRON PRP$
# children NOUN NNS
# using VERB VBG
# Federal PROPN NNP
# Taxpayer PROPN NNP
# Dollars PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 7 X LS
# . PUNCT .
# Promote PROPN NNP
# Love PROPN NNP
# of ADP IN
# Country PROPN NNP
# with ADP IN
# Authentic PROPN NNP
# Civics PROPN NNP
# Education PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# reinstate VERB VB
# the DET DT
# 1776 NUM CD
# Commission PROPN NNP
# , PUNCT ,
# promote VERB VB
# Fair PROPN NNP
# and CCONJ CC
# Patriotic PROPN NNP
# Civics PROPN NNPS
# Education PROPN NNP
# , PUNCT ,
# and CCONJ CC
# veto NOUN NN
# efforts NOUN NNS
# to PART TO
# nationalize VERB VB
# Civics PROPN NNP
# Education PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# support VERB VB
# schools NOUN NNS
# that PRON WDT
# teach VERB VBP
# America PROPN NNP
# 's PART POS
# Founding PROPN NNP
# Principles PROPN NNPS
# and CCONJ CC
# Western PROPN NNP
# Civilization PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 8 X LS
# . PUNCT .
# Freedom NOUN NN
# to AUX IN
# Pray PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# champion VERB VB
# the DET DT
# First PROPN NNP
# Amendment PROPN NNP
# Right NOUN NN
# to PART TO
# Pray VERB VB
# and CCONJ CC
# Read VERB VB
# the DET DT
# Bible PROPN NNP
# in ADP IN
# school NOUN NN
# , PUNCT ,
# and CCONJ CC
# stand VERB VB
# up ADP RP
# to ADP IN
# those PRON DT
# who PRON WP
# violate VERB VBP
# the DET DT
# Religious PROPN NNP
# Freedoms NOUN NNS
# of ADP IN
# American ADJ JJ
# students NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 9 X LS
# . PUNCT .
# Return VERB VB
# Education PROPN NNP
# to ADP IN
# the DET DT
# States PROPN NNP
#
#
#  SPACE _SP
# The DET DT
# United PROPN NNP
# States PROPN NNP
# spends VERB VBZ
# more ADJ JJR
# money NOUN NN
# per ADP IN
# pupil NOUN NN
# on ADP IN
# Education PROPN NNP
# than ADP IN
# any DET DT
# other ADJ JJ
# Country PROPN NNP
# in ADP IN
# the DET DT
# World PROPN NNP
# , PUNCT ,
# and CCONJ CC
# yet ADV RB
# we PRON PRP
# are AUX VBP
# at ADP IN
# the DET DT
# bottom NOUN NN
# of ADP IN
# every DET DT
# educational ADJ JJ
# list NOUN NN
# in ADP IN
# terms NOUN NNS
# of ADP IN
# results NOUN NNS
# . PUNCT .
# We PRON PRP
# are AUX VBP
# going VERB VBG
# to PART TO
# close VERB VB
# the DET DT
# Department PROPN NNP
# of ADP IN
# Education PROPN NNP
# in ADP IN
# Washington PROPN NNP
# , PUNCT ,
# D.C. PROPN NNP
# and CCONJ CC
# send VERB VB
# it PRON PRP
# back ADV RB
# to ADP IN
# the DET DT
# States PROPN NNPS
# , PUNCT ,
# where SCONJ WRB
# it PRON PRP
# belongs VERB VBZ
# , PUNCT ,
# and CCONJ CC
# let VERB VB
# the DET DT
# States PROPN NNP
# run VERB VB
# our PRON PRP$
# educational ADJ JJ
# system NOUN NN
# as SCONJ IN
# it PRON PRP
# should AUX MD
# be AUX VB
# run VERB VBN
# . PUNCT .
# Our PRON PRP$
# Great PROPN NNP
# Teachers PROPN NNPS
# , PUNCT ,
# who PRON WP
# are AUX VBP
# so ADV RB
# important ADJ JJ
# to ADP IN
# the DET DT
# future ADJ JJ
# wellbeing NOUN NN
# of ADP IN
# our PRON PRP$
# Country PROPN NNP
# , PUNCT ,
# will AUX MD
# be AUX VB
# cherished VERB VBN
# and CCONJ CC
# protected VERB VBN
# by ADP IN
# the DET DT
# Republican PROPN NNP
# Party PROPN NNP
# so SCONJ IN
# that SCONJ IN
# they PRON PRP
# can AUX MD
# do VERB VB
# the DET DT
# job NOUN NN
# of ADP IN
# educating VERB VBG
# our PRON PRP$
# students NOUN NNS
# that SCONJ IN
# they PRON PRP
# so ADV RB
# dearly ADV RB
# want VERB VBP
# to PART TO
# do VERB VB
# . PUNCT .
# It PRON PRP
# is AUX VBZ
# our PRON PRP$
# goal NOUN NN
# to PART TO
# bring VERB VB
# Education PROPN NNP
# in ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# to ADP IN
# the DET DT
# highest ADJ JJS
# level NOUN NN
# , PUNCT ,
# one NUM CD
# that PRON WDT
# it PRON PRP
# has AUX VBZ
# never ADV RB
# attained VERB VBN
# before ADV RB
# ! PUNCT .
#
#
#  SPACE _SP
# CHAPTER NOUN NN
# EIGHT NUM CD
# : PUNCT :
# BRING VERB VB
# COMMON ADJ JJ
# SENSE NOUN NN
# TO ADP IN
# GOVERNMENT NOUN NN
# AND CCONJ CC
# RENEW VERB VB
# THE DET DT
# PILLARS NOUN NNS
# OF ADP IN
# AMERICAN PROPN NNP
# CIVILIZATION PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# Republicans NOUN NNS
# offer VERB VBP
# a DET DT
# plan NOUN NN
# to PART TO
# renew VERB VB
# American PROPN NNP
# Civilization PROPN NNP
# with ADP IN
# Common PROPN NNP
# Sense PROPN NNP
# Policies PROPN NNPS
# that PRON WDT
# supports VERB VBZ
# families NOUN NNS
# , PUNCT ,
# restores VERB VBZ
# Law PROPN NNP
# and CCONJ CC
# Order PROPN NNP
# , PUNCT ,
# cares VERB VBZ
# for ADP IN
# Veterans PROPN NNPS
# , PUNCT ,
# promotes VERB VBZ
# beauty NOUN NN
# , PUNCT ,
# and CCONJ CC
# honors VERB VBZ
# American PROPN NNP
# History PROPN NNP
# . PUNCT .
# We PRON PRP
# commit VERB VBP
# to ADP IN
# strengthening VERB VBG
# the DET DT
# Foundations PROPN NNP
# of ADP IN
# our PRON PRP$
# Society PROPN NNP
# for ADP IN
# a DET DT
# brighter ADJ JJR
# future NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# Empower PROPN NNP
# American PROPN NNP
# Families PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# promote VERB VB
# a DET DT
# Culture NOUN NN
# that PRON WDT
# values VERB VBZ
# the DET DT
# Sanctity NOUN NN
# of ADP IN
# Marriage PROPN NNP
# , PUNCT ,
# the DET DT
# blessings NOUN NNS
# of ADP IN
# childhood NOUN NN
# , PUNCT ,
# the DET DT
# foundational ADJ JJ
# role NOUN NN
# of ADP IN
# families NOUN NNS
# , PUNCT ,
# and CCONJ CC
# supports VERB VBZ
# working VERB VBG
# parents NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# end VERB VB
# policies NOUN NNS
# that PRON WDT
# punish VERB VBP
# families NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Rebuild VERB VB
# Our PRON PRP$
# Cities PROPN NNP
# and CCONJ CC
# Restore PROPN NNP
# Law PROPN NNP
# and CCONJ CC
# Order PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# restore VERB VB
# safety NOUN NN
# in ADP IN
# our PRON PRP$
# neighborhoods NOUN NNS
# by ADP IN
# replenishing VERB VBG
# Police PROPN NNP
# Departments PROPN NNPS
# , PUNCT ,
# restoring VERB VBG
# Common PROPN NNP
# Sense PROPN NNP
# Policing PROPN NNP
# , PUNCT ,
# and CCONJ CC
# protecting VERB VBG
# Officers PROPN NNP
# from ADP IN
# frivolous ADJ JJ
# lawsuits NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# stand VERB VB
# up ADP RP
# to ADP IN
# Marxist PROPN NNP
# Prosecutors PROPN NNPS
# , PUNCT ,
# vigorously ADV RB
# defend VERB VB
# the DET DT
# Right NOUN NN
# of ADP IN
# every DET DT
# American PROPN NNP
# to PART TO
# live VERB VB
# in ADP IN
# peace NOUN NN
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# will AUX MD
# compassionately ADV RB
# address VERB VB
# homelessness NOUN NN
# to PART TO
# restore VERB VB
# order NOUN NN
# to ADP IN
# our PRON PRP$
# streets NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Make VERB VB
# Washington PROPN NNP
# D.C. PROPN NNP
# the DET DT
# Safest PROPN NNPS
# and CCONJ CC
# Most ADJ JJS
# Beautiful PROPN NNP
# Capital PROPN NNP
# City PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# reassert VERB VB
# greater ADJ JJR
# Federal PROPN NNP
# Control PROPN NNP
# over ADP IN
# Washington PROPN NNP
# , PUNCT ,
# DC PROPN NNP
# to PART TO
# restore VERB VB
# Law PROPN NNP
# and CCONJ CC
# Order PROPN NNP
# in ADP IN
# our PRON PRP$
# Capital PROPN NNP
# City PROPN NNP
# , PUNCT ,
# and CCONJ CC
# ensure VERB VB
# Federal PROPN NNP
# Buildings PROPN NNPS
# and CCONJ CC
# Monuments PROPN NNPS
# are AUX VBP
# well ADV RB
# - PUNCT HYPH
# maintained VERB VBN
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Take VERB VB
# Care PROPN NNP
# of ADP IN
# Our PRON PRP$
# Veterans PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# end VERB VB
# luxury NOUN NN
# housing PROPN NNP
# and CCONJ CC
# Taxpayer PROPN NNP
# benefits NOUN NNS
# for ADP IN
# Illegal PROPN NNP
# Immigrants PROPN NNPS
# and CCONJ CC
# use VERB VB
# those DET DT
# savings NOUN NNS
# to PART TO
# shelter VERB VB
# and CCONJ CC
# treat VERB VB
# homeless ADJ JJ
# Veterans PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# restore VERB VB
# Trump PROPN NNP
# Administration PROPN NNP
# reforms NOUN NNS
# to PART TO
# expand VERB VB
# Veterans PROPN NNPS
# ' PART POS
# Healthcare PROPN NNP
# Choices PROPN NNPS
# , PUNCT ,
# protect VERB VB
# Whistleblowers NOUN NNS
# , PUNCT ,
# and CCONJ CC
# hold VERB VB
# accountable ADJ JJ
# poorly ADV RB
# performing VERB VBG
# employees NOUN NNS
# not PART RB
# giving VERB VBG
# our PRON PRP$
# Veterans PROPN NNPS
# the DET DT
# care NOUN NN
# they PRON PRP
# deserve VERB VBP
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Make VERB VB
# Colleges PROPN NNPS
# and CCONJ CC
# Universities PROPN NNPS
# Sane PROPN NNP
# and CCONJ CC
# Affordable PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# fire VERB VB
# Radical PROPN NNP
# Left PROPN NNP
# accreditors NOUN NNS
# , PUNCT ,
# drive VERB VB
# down ADP RP
# Tuition NOUN NN
# costs NOUN NNS
# , PUNCT ,
# restore VERB VB
# Due PROPN NNP
# Process PROPN NNP
# protections NOUN NNS
# , PUNCT ,
# and CCONJ CC
# pursue VERB VB
# Civil PROPN NNP
# Rights PROPN NNPS
# cases NOUN NNS
# against ADP IN
# Schools PROPN NNP
# that PRON WDT
# discriminate VERB VBP
# . PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . PUNCT .
# Combat NOUN NN
# Antisemitism PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# condemn VERB VBP
# antisemitism NOUN NN
# , PUNCT ,
# and CCONJ CC
# support VERB VB
# ...
# of ADP IN
# law NOUN NN
# , PUNCT ,
# and CCONJ CC
# defending VERB VBG
# the DET DT
# Rights PROPN NNPS
# of ADP IN
# all DET DT
# Americans PROPN NNPS
# to ADP IN
# Life PROPN NNP
# , PUNCT ,
# Liberty PROPN NNP
# , PUNCT ,
# and CCONJ CC
# the DET DT
# Pursuit PROPN NNP
# of ADP IN
# Happiness PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# maintain VERB VB
# the DET DT
# Supreme PROPN NNP
# Court PROPN NNP
# as SCONJ IN
# it PRON PRP
# was AUX VBD
# always ADV RB
# meant VERB VBN
# to PART TO
# be AUX VB
# , PUNCT ,
# at ADP IN
# 9 NUM CD
# Justices NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# not PART RB
# allow VERB VB
# the DET DT
# Democrat PROPN NNP
# Party PROPN NNP
# to PART TO
# increase VERB VB
# this DET DT
# number NOUN NN
# , PUNCT ,
# as SCONJ IN
# they PRON PRP
# would AUX MD
# like VERB VB
# to PART TO
# do VERB VB
# , PUNCT ,
# by ADP IN
# 4 NUM CD
# , PUNCT ,
# 6 NUM CD
# , PUNCT ,
# 8 NUM CD
# , PUNCT ,
# 10 NUM CD
# , PUNCT ,
# and CCONJ CC
# even ADV RB
# 12 NUM CD
# Justices NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# block VERB VB
# them PRON PRP
# at ADP IN
# every DET DT
# turn NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Stop VERB VB
# Woke PROPN NNP
# and CCONJ CC
# Weaponized ADJ JJ
# Government NOUN NN
#
#
#  SPACE _SP
# We PRON PRP
# will AUX MD
# hold VERB VB
# accountable ADJ JJ
# those PRON DT
# who PRON WP
# have AUX VBP
# misused VERB VBN
# the DET DT
# power NOUN NN
# of ADP IN
# Government PROPN NNP
# to PART TO
# unjustly ADV RB
# prosecute VERB VB
# their PRON PRP$
# Political PROPN NNP
# Opponents PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# declassify VERB VB
# Government NOUN NN
# records NOUN NNS
# , PUNCT ,
# root VERB VB
# out ADP RP
# wrongdoers NOUN NNS
# , PUNCT ,
# and CCONJ CC
# fire VERB VB
# corrupt ADJ JJ
# employees NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Dismantle VERB VB
# Censorship PROPN NNP
# & CCONJ CC
# Protect VERB VB
# Free PROPN NNP
# Speech PROPN NNP
#
#
#  SPACE _SP
# We PRON PRP
# will AUX MD
# ban VERB VB
# the DET DT
# Federal PROPN NNP
# Government PROPN NNP
# from ADP IN
# colluding VERB VBG
# with ADP IN
# anyone PRON NN
# to PART TO
# censor VERB VB
# Lawful PROPN NNP
# Speech PROPN NNP
# , PUNCT ,
# defund ADJ JJ
# institutions NOUN NNS
# engaged VERB VBN
# in ADP IN
# censorship NOUN NN
# , PUNCT ,
# and CCONJ CC
# hold VERB VB
# accountable ADJ JJ
# all DET DT
# bureaucrats NOUN NNS
# involved VERB VBN
# with ADP IN
# illegal ADJ JJ
# censoring NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# protect VERB VB
# Free PROPN NNP
# Speech PROPN NNP
# online NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Defend VERB VB
# Religious PROPN NNP
# Liberty PROPN NNP
#
#
#  SPACE _SP
# We PRON PRP
# are AUX VBP
# the DET DT
# defenders NOUN NNS
# of ADP IN
# the DET DT
# First PROPN NNP
# Amendment PROPN NNP
# Right NOUN NN
# to ADP IN
# Religious PROPN NNP
# Liberty PROPN NNP
# . PUNCT .
# It PRON PRP
# protects VERB VBZ
# the DET DT
# Right NOUN NN
# not PART RB
# only ADV RB
# to PART TO
# Worship VERB VB
# according VERB VBG
# to ADP IN
# the DET DT
# dictates NOUN NNS
# of ADP IN
# Conscience PROPN NNP
# , PUNCT ,
# but CCONJ CC
# also ADV RB
# to PART TO
# act VERB VB
# in ADP IN
# accordance NOUN NN
# with ADP IN
# those DET DT
# Beliefs PROPN NNPS
# , PUNCT ,
# not PART RB
# just ADV RB
# in ADP IN
# places NOUN NNS
# of ADP IN
# Worship NOUN NN
# , PUNCT ,
# but CCONJ CC
# in ADP IN
# everyday ADJ JJ
# life NOUN NN
# . PUNCT .
# Our PRON PRP$
# ranks NOUN NNS
# include VERB VBP
# men NOUN NNS
# and CCONJ CC
# women NOUN NNS
# from ADP IN
# every DET DT
# Faith PROPN NNP
# and CCONJ CC
# Tradition PROPN NNP
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# respect VERB VBP
# the DET DT
# Right NOUN NN
# of ADP IN
# every DET DT
# American PROPN NNP
# to PART TO
# follow VERB VB
# his PRON PRP$
# or CCONJ CC
# her PRON PRP$
# deeply ADV RB
# held VERB VBN
# Beliefs PROPN NNP
# . PUNCT .
# To PART TO
# protect VERB VB
# Religious PROPN NNP
# Liberty PROPN NNP
# , PUNCT ,
# Republicans PROPN NNPS
# support VERB VBP
# a DET DT
# new ADJ JJ
# Federal PROPN NNP
# Task PROPN NNP
# Force PROPN NNP
# on ADP IN
# Fighting PROPN NNP
# Anti PROPN NNP
# - PROPN NNP
# Christian PROPN NNP
# Bias PROPN NNP
# that PRON WDT
# will AUX MD
# investigate VERB VB
# all DET DT
# forms NOUN NNS
# of ADP IN
# illegal ADJ JJ
# discrimination NOUN NN
# , PUNCT ,
# harassment NOUN NN
# , PUNCT ,
# and CCONJ CC
# persecution NOUN NN
# against ADP IN
# Christians PROPN NNPS
# in ADP IN
# America PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Protect VERB VB
# and CCONJ CC
# Defend VERB VB
# a DET DT
# Vote NOUN NN
# of ADP IN
# the DET DT
# People PROPN NNPS
# , PUNCT ,
# from ADP IN
# within ADP IN
# the DET DT
# States PROPN NNPS
# , PUNCT ,
# on ADP IN
# the DET DT
# Issue NOUN NN
# of ADP IN
# Life PROPN NNP
#
#
#  SPACE _SP
# We PRON PRP
# proudly ADV RB
# stand VERB VBP
# for ADP IN
# families NOUN NNS
# and CCONJ CC
# Life PROPN NNP
# . PUNCT .
# We PRON PRP
# believe VERB VBP
# that SCONJ IN
# the DET DT
# 14th ADJ JJ
# Amendment PROPN NNP
# to ADP IN
# the DET DT
# Constitution PROPN NNP
# of ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# guarantees VERB VBZ
# that SCONJ IN
# no DET DT
# person NOUN NN
# can AUX MD
# be AUX VB
# denied VERB VBN
# Life PROPN NNP
# or CCONJ CC
# Liberty PROPN NNP
# without ADP IN
# Due PROPN NNP
# Process PROPN NNP
# , PUNCT ,
# and CCONJ CC
# that SCONJ IN
# the DET DT
# States PROPN NNPS
# are AUX VBP
# , PUNCT ,
# therefore ADV RB
# , PUNCT ,
# free ADJ JJ
# to PART TO
# pass VERB VB
# Laws NOUN NNS
# protecting VERB VBG
# those DET DT
# Rights NOUN NNS
# . PUNCT .
# After ADP IN
# 51 NUM CD
# years NOUN NNS
# , PUNCT ,
# because SCONJ IN
# of ADP IN
# us PRON PRP
# , PUNCT ,
# that DET DT
# power NOUN NN
# has AUX VBZ
# been AUX VBN
# given VERB VBN
# to ADP IN
# the DET DT
# States PROPN NNP
# and CCONJ CC
# to ADP IN
# a DET DT
# vote NOUN NN
# of ADP IN
# the DET DT
# People PROPN NNPS
# . PUNCT .
# We PRON PRP
# will AUX MD
# oppose VERB VB
# Late ADJ JJ
# Term PROPN NNP
# Abortion PROPN NNP
# , PUNCT ,
# while SCONJ IN
# supporting VERB VBG
# mothers NOUN NNS
# and CCONJ CC
# policies NOUN NNS
# that PRON WDT
# advance VERB VBP
# Prenatal PROPN NNP
# Care PROPN NNP
# , PUNCT ,
# access NOUN NN
# to ADP IN
# Birth PROPN NNP
# Control PROPN NNP
# , PUNCT ,
# and CCONJ CC
# IVF PROPN NNP
# ( PUNCT -LRB-
# fertility NOUN NN
# treatments NOUN NNS
# ) PUNCT -RRB-
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# End VERB VB
# Left ADJ JJ
# - PUNCT HYPH
# wing NOUN NN
# Gender PROPN NNP
# Insanity PROPN NNP
#
#
#  SPACE _SP
# We PRON PRP
# will AUX MD
# keep VERB VB
# men NOUN NNS
# out ADP IN
# of ADP IN
# women NOUN NNS
# 's PART POS
# sports NOUN NNS
# , PUNCT ,
# ban NOUN NN
# Taxpayer PROPN NNP
# funding NOUN NN
# for ADP IN
# sex NOUN NN
# change NOUN NN
# surgeries NOUN NNS
# , PUNCT ,
# and CCONJ CC
# stop VERB VB
# Taxpayer PROPN NNP
# - PUNCT HYPH
# funded VERB VBN
# Schools PROPN NNPS
# from ADP IN
# promoting VERB VBG
# gender NOUN NN
# transition NOUN NN
# , PUNCT ,
# reverse VERB VB
# Biden PROPN NNP
# 's PART POS
# radical ADJ JJ
# rewrite NOUN NN
# of ADP IN
# Title PROPN NNP
# IX PROPN NNP
# Education PROPN NNP
# Regulations PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# restore VERB VB
# protections NOUN NNS
# for ADP IN
# women NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Ensure VERB VB
# Election PROPN NNP
# Integrity PROPN NNP
#
#
#  SPACE _SP
# We PRON PRP
# will AUX MD
# implement VERB VB
# measures NOUN NNS
# to PART TO
# secure VERB VB
# our PRON PRP$
# Elections NOUN NNS
# , PUNCT ,
# including VERB VBG
# Voter PROPN NNP
# ID PROPN NNP
# , PUNCT ,
# highly ADV RB
# sophisticated ADJ JJ
# paper NOUN NN
# ballots NOUN NNS
# , PUNCT ,
# proof NOUN NN
# of ADP IN
# Citizenship PROPN NNP
# , PUNCT ,
# and CCONJ CC
# same ADJ JJ
# day NOUN NN
# Voting NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# not PART RB
# allow VERB VB
# the DET DT
# Democrats PROPN NNPS
# to PART TO
# give VERB VB
# Voting PROPN NNP
# Rights PROPN NNPS
# to PART TO
# illegal ADJ JJ
# Aliens PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 7 X LS
# . X LS
# Republicans PROPN NNPS
# Will AUX MD
# Protect VERB VB
# Americans PROPN NNPS
# in ADP IN
# the DET DT
# Territories PROPN NNPS
# . PUNCT .
#
#
#  SPACE _SP
# The DET DT
# territories NOUN NNS
# of ADP IN
# Guam PROPN NNP
# , PUNCT ,
# the DET DT
# Commonwealth PROPN NNP
# of ADP IN
# the DET DT
# Northern PROPN NNP
# Mariana PROPN NNP
# Islands PROPN NNPS
# , PUNCT ,
# American PROPN NNP
# Samoa PROPN NNP
# , PUNCT ,
# the DET DT
# U.S. PROPN NNP
# Virgin PROPN NNP
# Islands PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Puerto PROPN NNP
# Rico PROPN NNP
# are AUX VBP
# of ADP IN
# vital ADJ JJ
# importance NOUN NN
# to ADP IN
# our PRON PRP$
# National PROPN NNP
# Security PROPN NNP
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# welcome VERB VBP
# their PRON PRP$
# greater ADJ JJR
# participation NOUN NN
# in ADP IN
# all DET DT
# aspects NOUN NNS
# of ADP IN
# the DET DT
# political ADJ JJ
# process NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# CHAPTER PROPN NNP
# TEN PROPN NNP
# : PUNCT :
# RETURN NOUN NN
# TO ADP IN
# PEACE PROPN NNP
# THROUGH ADP IN
# STRENGTH PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Commitment PROPN NNP
# : PUNCT :
#
#
#  SPACE _SP
# Keeping VERB VBG
# the DET DT
# American PROPN NNP
# People PROPN NNPS
# safe ADJ JJ
# requires VERB VBZ
# a DET DT
# strong ADJ JJ
# America PROPN NNP
# . PUNCT .
# The DET DT
# Biden PROPN NNP
# administration NOUN NN
# 's PART POS
# weak ADJ JJ
# Foreign PROPN NNP
# Policy PROPN NNP
# has AUX VBZ
# made VERB VBN
# us PRON PRP
# less ADV RBR
# safe ADJ JJ
# and CCONJ CC
# a DET DT
# laughingstock NOUN NN
# all ADV RB
# over ADP IN
# the DET DT
# World NOUN NN
# . PUNCT .
# The DET DT
# Republican PROPN NNP
# Plan PROPN NNP
# is AUX VBZ
# to PART TO
# return VERB VB
# Peace NOUN NN
# through ADP IN
# Strength PROPN NNP
# , PUNCT ,
# rebuilding VERB VBG
# our PRON PRP$
# Military PROPN NNP
# and CCONJ CC
# Alliances PROPN NNPS
# , PUNCT ,
# countering VERB VBG
# China PROPN NNP
# , PUNCT ,
# defeating VERB VBG
# terrorism NOUN NN
# , PUNCT ,
# building VERB VBG
# an DET DT
# Iron PROPN NNP
# Dome PROPN NNP
# Missile PROPN NNP
# Defense PROPN NNP
# Shield PROPN NNP
# , PUNCT ,
# promoting VERB VBG
# American PROPN NNP
# Values PROPN NNPS
# , PUNCT ,
# securing VERB VBG
# our PRON PRP$
# Homeland PROPN NNP
# and CCONJ CC
# Borders PROPN NNP
# , PUNCT ,
# and CCONJ CC
# reviving VERB VBG
# our PRON PRP$
# Defense PROPN NNP
# Industrial PROPN NNP
# Base PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# build VERB VB
# a DET DT
# Military PROPN NNP
# bigger ADJ JJR
# , PUNCT ,
# better ADJ JJR
# , PUNCT ,
# and CCONJ CC
# stronger ADJ JJR
# than ADP IN
# ever ADV RB
# before ADV RB
# . PUNCT .
# Our PRON PRP$
# full ADJ JJ
# commitment NOUN NN
# is AUX VBZ
# to ADP IN
# protecting VERB VBG
# America PROPN NNP
# and CCONJ CC
# ensuring VERB VBG
# a DET DT
# safe ADJ JJ
# and CCONJ CC
# prosperous ADJ JJ
# future NOUN NN
# for ADP IN
# all PRON DT
# . PUNCT .
#
#
#  SPACE _SP
# 1 X LS
# . PUNCT .
# The DET DT
# National PROPN NNP
# Interest PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# promote VERB VB
# a DET DT
# Foreign PROPN NNP
# Policy PROPN NNP
# centered VERB VBD
# on ADP IN
# the DET DT
# most ADV RBS
# essential ADJ JJ
# American PROPN NNP
# Interests PROPN NNP
# , PUNCT ,
# starting VERB VBG
# with ADP IN
# protecting VERB VBG
# the DET DT
# American PROPN NNP
# Homeland PROPN NNP
# , PUNCT ,
# our PRON PRP$
# People NOUN NNS
# , PUNCT ,
# our PRON PRP$
# Borders PROPN NNPS
# , PUNCT ,
# our PRON PRP$
# Great ADJ JJ
# American PROPN NNP
# Flag PROPN NNP
# , PUNCT ,
# and CCONJ CC
# our PRON PRP$
# Rights NOUN NNS
# under ADP IN
# God PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 2 X LS
# . X LS
# Modernize VERB VB
# the DET DT
# Military PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# ensure VERB VB
# our PRON PRP$
# Military PROPN NNP
# is AUX VBZ
# the DET DT
# most ADV RBS
# modern ADJ JJ
# , PUNCT ,
# lethal ADJ JJ
# and CCONJ CC
# powerful ADJ JJ
# Force PROPN NNP
# in ADP IN
# the DET DT
# World PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# invest VERB VB
# in ADP IN
# cutting VERB VBG
# - PUNCT HYPH
# edge NOUN NN
# research NOUN NN
# and CCONJ CC
# advanced ADJ JJ
# technologies NOUN NNS
# , PUNCT ,
# including VERB VBG
# an DET DT
# Iron PROPN NNP
# Dome PROPN NNP
# Missile PROPN NNP
# Defense PROPN NNP
# Shield PROPN NNP
# , PUNCT ,
# support VERB VB
# our PRON PRP$
# Troops NOUN NNS
# with ADP IN
# higher ADJ JJR
# pay NOUN NN
# , PUNCT ,
# and CCONJ CC
# get VERB VB
# woke VERB VBN
# Leftwing PROPN NNP
# Democrats PROPN NNPS
# fired VERB VBD
# as ADV RB
# soon ADV RB
# as ADP IN
# possible ADJ JJ
# . PUNCT .
#
#
#  SPACE _SP
# 3 X LS
# . PUNCT .
# Strengthen VERB VB
# Alliances PROPN NNPS
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# strengthen VERB VB
# Alliances NOUN NNS
# by ADP IN
# ensuring VERB VBG
# that SCONJ IN
# our PRON PRP$
# Allies PROPN NNPS
# must AUX MD
# meet VERB VB
# their PRON PRP$
# obligations NOUN NNS
# to PART TO
# invest VERB VB
# in ADP IN
# our PRON PRP$
# Common PROPN NNP
# Defense PROPN NNP
# and CCONJ CC
# by ADP IN
# restoring VERB VBG
# Peace PROPN NNP
# to ADP IN
# Europe PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# stand VERB VB
# with ADP IN
# Israel PROPN NNP
# , PUNCT ,
# and CCONJ CC
# seek VERB VB
# peace NOUN NN
# in ADP IN
# the DET DT
# Middle PROPN NNP
# East PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# rebuild VERB VB
# our PRON PRP$
# Alliance PROPN NNP
# Network PROPN NNP
# in ADP IN
# the DET DT
# Region PROPN NNP
# to PART TO
# ensure VERB VB
# a DET DT
# future NOUN NN
# of ADP IN
# Peace PROPN NNP
# , PUNCT ,
# Stability PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Prosperity PROPN NNP
# . PUNCT .
# Likewise ADV RB
# , PUNCT ,
# we PRON PRP
# will AUX MD
# champion VERB VB
# Strong PROPN NNP
# , PUNCT ,
# Sovereign PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Independent PROPN NNP
# Nations PROPN NNPS
# in ADP IN
# the DET DT
# Indo PROPN NNP
# - PUNCT HYPH
# Pacific PROPN NNP
# , PUNCT ,
# thriving VERB VBG
# in ADP IN
# Peace PROPN NNP
# and CCONJ CC
# Commerce PROPN NNP
# with ADP IN
# others NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# 4 X LS
# . PUNCT .
# Strengthen VERB VB
# Economic PROPN NNP
# , PUNCT ,
# Military PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Diplomatic PROPN NNP
# Capabilities PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# strengthen VERB VB
# Economic PROPN NNP
# , PUNCT ,
# Military PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Diplomatic ADJ JJ
# capabilities NOUN NNS
# to PART TO
# protect VERB VB
# the DET DT
# American ADJ JJ
# way NOUN NN
# of ADP IN
# life NOUN NN
# from ADP IN
# the DET DT
# malign NOUN NN
# influences NOUN NNS
# of ADP IN
# Countries PROPN NNPS
# that PRON WDT
# stand VERB VBP
# against ADP IN
# us PRON PRP
# around ADP IN
# the DET DT
# World PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 5 X LS
# . PUNCT .
# Defend PROPN NNP
# America PROPN NNP
# 's PART POS
# Borders PROPN NNP
#
#
#  SPACE _SP
# Against ADP IN
# all DET DT
# odds NOUN NNS
# , PUNCT ,
# President PROPN NNP
# Trump PROPN NNP
# has AUX VBZ
# completed VERB VBN
# Hundreds NOUN NNS
# of ADP IN
# Miles PROPN NNP
# of ADP IN
# Wall PROPN NNP
# , PUNCT ,
# and CCONJ CC
# he PRON PRP
# will AUX MD
# quickly ADV RB
# finish VERB VB
# the DET DT
# job NOUN NN
# . PUNCT .
# Republicans PROPN NNPS
# will AUX MD
# mobilize VERB VB
# Military ADJ JJ
# personnel NOUN NNS
# and CCONJ CC
# assets NOUN NNS
# as ADP IN
# necessary ADJ JJ
# to PART TO
# crack VERB VB
# down ADP RP
# hard ADV RB
# on ADP IN
# the DET DT
# cartels NOUN NNS
# that SCONJ IN
# traffic NOUN NN
# drugs NOUN NNS
# and CCONJ CC
# people NOUN NNS
# into ADP IN
# our PRON PRP$
# Country PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 6 X LS
# . PUNCT .
# Revive VERB VB
# our PRON PRP$
# Industrial PROPN NNP
# Base PROPN NNP
#
#
#  SPACE _SP
# Our PRON PRP$
# Industrial PROPN NNP
# Base PROPN NNP
# is AUX VBZ
# critical ADJ JJ
# to ADP IN
# ensuring VERB VBG
# good ADJ JJ
# jobs NOUN NNS
# for ADP IN
# our PRON PRP$
# people NOUN NNS
# but CCONJ CC
# also ADV RB
# the DET DT
# reliable ADJ JJ
# production NOUN NN
# of ADP IN
# vital ADJ JJ
# Defense PROPN NNP
# platforms NOUN NNS
# and CCONJ CC
# supplies NOUN NNS
# . PUNCT .
# Our PRON PRP$
# Policy NOUN NN
# must AUX MD
# be AUX VB
# to PART TO
# revive VERB VB
# our PRON PRP$
# Industrial PROPN NNP
# Base PROPN NNP
# , PUNCT ,
# with ADP IN
# priority NOUN NN
# on ADP IN
# Defense NOUN NN
# - PUNCT HYPH
# critical ADJ JJ
# industries NOUN NNS
# . PUNCT .
# Equipment NOUN NN
# and CCONJ CC
# parts NOUN NNS
# critical ADJ JJ
# to ADP IN
# American PROPN NNP
# Security PROPN NNP
# must AUX MD
# be AUX VB
# MADE VERB VBN
# IN ADP IN
# THE DET DT
# USA PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# 7 X LS
# . PUNCT .
# Protect VERB VB
# Critical PROPN NNP
# Infrastructure PROPN NNP
#
#
#  SPACE _SP
# Republicans PROPN NNPS
# will AUX MD
# use VERB VB
# all DET DT
# tools NOUN NNS
# of ADP IN
# National PROPN NNP
# Power PROPN NNP
# to PART TO
# protect VERB VB
# our PRON PRP$
# Nation PROPN NNP
# 's PART POS
# Critical PROPN NNP
# Infrastructure PROPN NNP
# and CCONJ CC
# Industrial PROPN NNP
# Base PROPN NNP
# from ADP IN
# malicious ADJ JJ
# cyber NOUN NN
# actors NOUN NNS
# . PUNCT .
# This PRON DT
# will AUX MD
# be AUX VB
# a DET DT
# National PROPN NNP
# Priority PROPN NNP
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# will AUX MD
# both ADV RB
# raise VERB VB
# the DET DT
# Security PROPN NNP
# Standards PROPN NNPS
# for ADP IN
# our PRON PRP$
# Critical PROPN NNP
# Systems PROPN NNPS
# and CCONJ CC
# Networks PROPN NNPS
# and CCONJ CC
# defend VERB VB
# them PRON PRP
# against ADP IN
# bad ADJ JJ
# actors NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP

# %% [markdown]
# ### Extracting words by part of speech
#
# Now we can write simple code to extract and recombine words by their part of speech. The following code creates two lists, one for all the nouns and another for all of the adjectives in the Republican platform:

# %%
nouns = []
adjectives = []

for word in dem_plat_doc:
    if word.pos_ == 'NOUN' and word.text not in nouns:
        nouns.append(word.text)
    elif word.pos_ == 'ADJ' and word.text not in adjectives:
        adjectives.append(word.text)

print("here are the first 20 nouns: " + str(nouns[0:19]))
print("and here are the first 20 adjectives: " + str(adjectives[0:19]))
# Out:
# here are the first 20 nouns: ['values', 'lands', 'centuries', 'ancestors', 'descendants', 'time', 'communities', 'continent', 'country', 'homelands', 'respects', 'millions', 'people', 'history', 'waters', 'animals', 'tribes', 'area', 'homeland']
# and here are the first 20 adjectives: ['many', 'immemorial', 'native', 'Indigenous', 'traditional', 'other', 'first', 'nay', 'nearby', 'more', 'less', 'More', 'fewer', 'rich', 'powerful', 'fair', 'high', 'global', 'pandemic']

# %% [markdown]
# And below, for levity, some code to print out random pairings of an adjective from the text with a noun from the text:

# %%
import random
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
# Out:
# solitary jurisdictions
# burdensome reforms
# commercial giveaway
# broad recruiting

# %% [markdown]
# ### **Excercise #1**

# %% [markdown]
# Remember from a few cells up above how the `.tag_` attribute allows us to be even more specific thtan the `.pos` attribute about the parts of speech we want?
#
# How would we iterate through the words included in the Republican platform to get a list of only verbs in the past participle?
#
# *Hint: you'll find the name of the tag you're looking for [here](https://spacy.io/api/annotation#pos-tagging). Click on "English" to expand.*

# %%
# your code here

# %%
past_participles = []

for word in dem_plat_doc:
    if word.tag_ == 'VBN' and word.text not in past_participles:
        past_participles.append(word.text)

past_participles[0:10]
# Out:
# ['been',
#  'stewarded',
#  'built',
#  'protected',
#  'known',
#  'recognized',
#  'created',
#  'started',
#  'expanded',
#  'exposed']

# %% [markdown]
# ## Larger syntactic units
#
# So we can get individual words by their part of speech. Great! But what if we want larger chunks, based on their syntactic role in the sentence? The easy way is `.noun_chunks`, which is an attribute of a document or a sentence that evaluates to a list of [spans](https://spacy.io/docs/api/span) of noun phrases, regardless of their position in the document:

# %%
for item in dem_plat_doc.noun_chunks:
    print(item.text)
# Out:
# Streaming output truncated to the last 5000 lines.
# infectious diseases
# HIV
# Hepatitis C
# access
# PrEP
# the HIV epidemic
# We
# a long way
# the full promise
# America
# we
# a party
# the work
# a nation
# all people
# their lives
# right historical wrongs
# Democrats
# Congress
# a study
# reparations
# the continuing impacts
# slavery
# Trump's vision
# America
# President
# he
# Black-owned businesses
# it
# time
# relief funds
# His tax law
# wealthy white Americans
# everyone
# Unemployment rates
# his presidency
# people
# color
# he
# health care
# affordable housing
# Social Security
# a real estate developer
# he
# race-based housing discrimination
# systemic violations
# the Fair Housing Act
# racial segregation
# discrimination
# properties
# they
# he
# the Affordable Care Act
# health care
# millions
# He
# President Biden's landmark jobs
# prescription drug
# climate bills
# a crippling import tax
# the everyday things
# people
# costs
# Black and Latino families
# everything
# insulin
# internet
# school supplies
# He
# the racial wealth gap
# taxes
# billionaires
# big corporations
# working families
# the bill
# He
# our communities
# the murder rate
# a record
# his presidency
# crime
# President Biden
# Trump
# his hand-picked courts
# their attacks
# our rights
# freedoms
# voting rights
# the freedom
# freedom
# one's own healthcare decisions
# America
# generations
# LGBTQI+ Americans
# the courage
# it
# their lives
# livelihoods
# risk
# LGBTQI+ Americans
# hope
# all people
# a life
# who
# they
# every aspect
# American life
# the fight
# equality
# the LGBTQI+ community
# attacks
# bigotry
# states
# the country
# Democrats
# LGBTQI+ rights
# President Biden
# the most pro-equality Administration
# history
# Democrats
# President Biden
# the historic Respect
# Marriage Act
# marriage equality
# federal law
# He
# Trump's un-American ban
# transgender servicemembers
# the disgraceful and discriminatory ban
# blood donation
# gay and bisexual men
# Day
# his presidency
# he
# a historic executive order
# federal nondiscrimination protections
# LGBTQI+ people
# he
# executive orders
# civil rights protections
# housing
# employment
# health care
# education
# the justice system
# He
# service members
# provisions
# children
# who
# dependents
# their parents' temporary visas
# the United States
# their families
# provisions
# applications
# risk
# the U.S. Refugee Admissions Program
# a process
# Afghan evacuees
# their status
# lawful permanent resident
# Legislation
# work authorization
# those
# who
# lawful visa pathways
# families
# the path
# economic self-sufficiency
# This
# K-1
# K-2
# K-3 nonimmigrant visa holders
# fiancés
# spouses
# children
# U.S. citizens
# the spouses
# children
# high-skilled temporary visa holders
# Democrats
# opportunities
# work permits
# immigrants
# long-term undocumented residents
# asylum seekers
# our country
# Congress
# the number
# visas
# the Special Immigrant Juvenile Status program
# abused, abandoned, or neglected youth
# actions
# the Administration
# deferred action and work authorization
# juveniles
# this program
# Families
# Long-Term Undocumented Individuals
# Dreamers
# then-Vice President Biden
# President Obama
# the Deferred Action
# Childhood Arrivals (DACA) program
# President Biden
# steps
# undocumented people
# families
# Dreamers and DACA recipients
# President Biden
# DACA
# legal challenges
# the courts
# Affordable Care Act coverage
# DACA recipients
# the first time
# addition
# President Biden
# action
# it
# Dreamers
# DACA recipients
# who
# a higher education degree
# the United States
# a job offer
# work visas
# the Administration
# undocumented workers
# labor disputes
# deferred action
# they
# violations
# labor law
# Trump
# the DACA program
# his first term
# President Biden
# new actions
# an estimated 500,000 American families
# certain noncitizen spouses
# children
# U.S. citizens
# who
# the country
# 10 years
# lawful permanent residence
# a status
# they
# the country
# The average beneficiary
# the United States
# more than 20 years
# the shadows
# our communities
# President Biden
# steps
# Temporary Protected
# Status
# (TPS
# individuals
# countries
# armed conflicts
# natural disasters
# other crises
# thousands
# authorization
# the United States
# fear
# deportation
# a temporary period
# DHS
# which
# the program
# Afghanistan
# Cameroon
# Ethiopia
# Myanmar
# Ukraine
# Venezuela
# the list
# TPS-eligible countries
# DHS
# TPS
# immigrants
# most countries
# that
# TPS
# the countries
# that
# Trump
# Congress
# legislation
# a pathway
# Dreamers
# farmworkers
# careworkers
# other long-term undocumented individuals
# who
# this country
# taxes
# their local economies
# his second term
# President Biden
# them
# Efficient Immigration Decisions
#
# Immigration officers
# the right decisions
# they
# them
# the Administration
# U.S. Citizenship and Immigration Services
# USCIS
# processing times
# those
# work authorization
# immigration decisions
# naturalization and work permit applications
# April
# the Administration
# the lowest wait time
# naturalization
# work authorization documents
# certain categories
# applicants
# FY
# the oath
# allegiance
# more than 878,500 new U.S. citizens
# 12,000 members
# the military
# the backlog
# naturalization applications
# It
# the median processing time
# naturalization
# 10.5 months
# 6.1 months
# The Administration
# state governments
# non-profit groups
# Work Authorization Clinics
# which
# the burden
# American communities
# migrants
# their families
# emergency shelter
# more stable housing options
# It
# community-based organizations
# that
# host clinics
# immigration cases
# scheduling appointments
# U.S. ports
# entry
# the Administration
# CBPOne
# a free online tool
# migrants
# parts
# Mexico
# Scheduling appointments
# the process
# our border
# the advance information
# that
# CBP
# a more efficient and streamlined process
# CBP
# individuals
# CBPOne
# administrative processing capacity
# its introduction
# the President's Unity Agenda
# the day
# he
# office
# President Biden
# a president
# all Americans
# He
# we
# we
# his first State
# the Union
# President Biden
# a unity agenda
# COMPETITION
#
# Tech platforms
# companies
# us
# ideas
# innovation
# a global marketplace
# the same time
# they
# share
# data
# our children's mental health
# extremism
# polarization
# scientific evidence
# what
# so many Americans
# Social media
# other online platforms
# our mental health
# well-being
# our kids
# addition
# a handful
# dominant tech platforms
# companies
# the market
# them
# enormous power
# Americans' daily lives
# that power
# competitors
# consumers
# innovation
# President Biden
# all companies
# technology companies
# the harm
# they
# The president
# the alarm
# social media
# other platforms
# cyberstalking
# child sexual exploitation
# non-consensual intimate images
# their sites
# Democrats
# Republicans
# legislation
# these issues
# The Surgeon General
# an advisory warning
# the impacts
# social media
# youth mental health
# he
# social media
# children
# adolescents
# Democrats
# bipartisan legislation
# kids' privacy
# Big Tech
# personal data
# kids
# teenagers
# targeted advertising
# children
# stricter limits
# the personal data
# these companies
# all
# us
# the Administration
# legal protections
# survivors
# victims
# non-consensual intimate imagery
# those
# AI
# the federal civil cause
# action
# Women
# President Biden
# Democrats
# Republicans
# bipartisan legislation
# competition
# privacy
# the tech industry
# Important policies
# interoperability
# tech services
# platforms
# users
# their data
# large platforms
# their own products
# services
# an unfair advantage
# the marketplace
# We
# Section
# the Communications Decency Act
# which
# tech platforms
# liability
# they
# violent or illegal content
# platforms
# responsibility
# the content
# they
# Democrats
# data privacy
# The President
# an Executive Order
# America's sensitive personal data
# commercial data brokers
# identity thieves
# foreign intelligence actors
# the Federal Trade Commission
# commercial surveillance
# technology companies
# children's data
# We
# the Consumer Privacy Bill
# Rights
# student data privacy
# what
# schools
# education
# the Electronic Communications Privacy Act
# personal electronic information
# safeguard location information
# the Promise
# the Risks
# AI
#
# Artificial intelligence
# AI
# extraordinary potential
# both promise
# peril
# AI
# diseases
# the weather
# education
# it
# voices
# fraud
# institutionalize bias
# democracy
# We
# the promise
# AI
# its risks
# AI
# the public interest
# Democrats
# solutions
# AI's capabilities
# we
# the implications
# Americans' rights
# safety
# security
# President Biden
# a landmark Executive Order
# federal agencies
# new high standards
# AI safety
# security
# Americans' privacy
# advance equity
# civil rights
# workers
# consumers
# competitive markets
# AI development
# use
# Democrats
# workers
# a voice
# AI
# their workplace
# they
# any economic gains AI
# We
# AI
# discrimination
# bias
# other abuses
# justice
# health care
# education
# housing
# That
# the Administration
# action
# the Blueprint
# an AI Bill
# Rights
# new guidance
# federal agencies
# algorithmic discrimination
# the economy
# AI
# it
# we
# the brightest minds
# new technologies
# The Administration
# an AI Talent Surge
# AI professionals
# the federal government
# a pilot program
# successful initiatives
# additional scientists
# AI
# the AI Safety Institute
# the National Institute
# Standards
# Technology
# NIST
# rigorous standards
# extensive testing
# powerful AI models
# safety
# public release
# President Biden's second term
# Democrats
# the safe and secure development
# AI
# We
# the AI Safety Institute
# guidelines
# tools
# benchmarks
# best practices
# dangerous capabilities
# AI risk
# We
# funding
# critical AI research
# development
# that
# AI safety
# We
# voice impersonations
# President Biden
# action
# heightened protections
# critical sectors
# health care
# financial services
# education
# housing
# transportation
# we
# we
# transformative AI
# the federal government
# CANCER
# WE
# IT
#
# Cancer
# nearly every single American family
# the PRC
# North Korea
# their nuclear arsenals
# the context
# Iran
# uranium
# dangerous levels
# the Administration
# what
# it
# a nuclear power
# Nuclear war
# The United States
# only what
# openness
# future arms control negotiations
# competitors
# The Administration
# each leg
# our nuclear triad
# our command
# control
# communication systems
# our nuclear enterprise
# we
# if necessary capabilities
# posture
# President Biden
# U.S. doctrine
# U.S. nuclear weapons
# strategic attack
# those
# that
# us
# our allies
# partners
# nuclear weapons
# Trump
# the values
# that
# our military swears
# he
# our service members "suckers
# "losers
# He
# America
# he
# the values
# our military
# that
# us
# President Biden
# his back
# our military
# his second term
# he
# next-generation weapon systems
# cutting-edge training opportunities
# deterrence capabilities
# our submarine force
# the nuclear triad
# He
# cyber threats
# the capacity
# our intelligence communities
# the development
# rules
# the road
# technologies
# artificial intelligence
# he
# our veterans
# military families
# additional pay raises
# service members
# accessible and affordable childcare
# our military families
# , good-paying job opportunities
# military spouses
# effective suicide
# sexual assault prevention programs
# benefits
# our veterans
# their families

# %% [markdown]
# For anything more sophisticated than this, though, we'll need to learn about how spaCy parses sentences into its syntactic components.

# %% [markdown]
# ### Understanding dependency grammars

# %% [markdown]
# ![syntax_example.png](data:image/png;base64,...)

# %% [markdown]
# The idea of a dependency grammar is that every word in a sentence is a "dependent" on some other word, which is that word's "head." Those "head" words are in turn dependents of other words. The finite verb in the sentence is the ultimate "head" of the sentence, and is not itself dependent on any other word. (The dependents of a particular head are sometimes called its "children.")
#
# The question of how to know what constitutes a "head" and a "dependent" is complicated. As a starting point, here's a passage from [Dependency Grammar and Dependency Parsing](http://stp.lingfil.uu.se/~nivre/docs/05133.pdf):
#
# > Here are some of the criteria that have been proposed for identifying a syntactic relation between a head H and a dependent D in a construction C (Zwicky, 1985; Hudson, 1990):
# >
# > 1. H determines the syntactic category of C and can often replace C.
# > 2. H determines the semantic category of C; D gives semantic specification.
# > 3. H is obligatory; D may be optional.
# > 4. H selects D and determines whether D is obligatory or optional.
# > 5. The form of D depends on H (agreement or government).
# > 6. The linear position of D is specified with reference to H."
#
# There are different *types* of relationships between heads and dependents, and each type of relation has its own name.
#
# **Visit [the displaCy visualizer](https://demos.explosion.ai/displacy/?text=Everyone%20has%20the%20right%20to%20life%2C%20liberty%20and%20security%20of%20person&model=en&cpu=1&cph=0) to see how a particular sentence is parsed, and what the relations between the heads and dependents are.**

# %% [markdown]
# Here's a list of a few dependency relations and what they mean. ([A more complete list can be found here.](http://www.mathcs.emory.edu/~choi/doc/clear-dependency-2012.pdf))
#
# * `nsubj`: this word's head is a verb, and this word is itself the subject of the verb
# * `nsubjpass`: same as above, but for subjects in sentences in the passive voice
# * `dobj`: this word's head is a verb, and this word is itself the direct object of the verb
# * `iobj`: same as above, but indirect object
# * `aux`: this word's head is a verb, and this word is an "auxiliary" verb (like "have", "will", "be")
# * `attr`: this word's head is a copula (like "to be"), and this is the description attributed to the subject of the sentence (e.g., in "This product is a global brand", `brand` is dependent on `is` with the `attr` dependency relation)
# * `det`: this word's head is a noun, and this word is a determiner of that noun (like "the," "this," etc.)
# * `amod`: this word's head is a noun, and this word is an adjective describing that noun
# * `prep`: this word is a preposition that modifies its head
# * `pobj`: this word is a dependent (object) of a preposition

# %%
# Let's take a look at how this works in practice
# We'll go back to using our first doc, the Universal Declaration of Human Rights, for the rest of this notebook

# uncomment if this var needs to be reloaded
# doc = nlp("All human beings are born free and equal in dignity and rights. They are endowed with reason and conscience and should act towards one another in a spirit of brotherhood. Everyone has the right to life, liberty and security of person.")

for word in list(doc.sents)[2]:
    print("Word:", word.text)
    print("Tag:", word.tag_)
    print("Head:", word.head.text)
    print("Dependency relation:", word.dep_)
    print("Children:", list(word.children))
    print("")
# Out:
# Word: Everyone
# Tag: NN
# Head: has
# Dependency relation: nsubj
# Children: []
#
# Word: has
# Tag: VBZ
# Head: has
# Dependency relation: ROOT
# Children: [Everyone, right, .]
#
# Word: the
# Tag: DT
# Head: right
# Dependency relation: det
# Children: []
#
# Word: right
# Tag: NN
# Head: has
# Dependency relation: dobj
# Children: [the, to]
#
# Word: to
# Tag: IN
# Head: right
# Dependency relation: prep
# Children: [life]
#
# Word: life
# Tag: NN
# Head: to
# Dependency relation: pobj
# Children: [,, liberty]
#
# Word: ,
# Tag: ,
# Head: life
# Dependency relation: punct
# Children: []
#
# Word: liberty
# Tag: NN
# Head: life
# Dependency relation: conj
# Children: [and, security, of]
#
# Word: and
# Tag: CC
# Head: liberty
# Dependency relation: cc
# Children: []
#
# Word: security
# Tag: NN
# Head: liberty
# Dependency relation: conj
# Children: []
#
# Word: of
# Tag: IN
# Head: liberty
# Dependency relation: prep
# Children: [person]
#
# Word: person
# Tag: NN
# Head: of
# Dependency relation: pobj
# Children: []
#
# Word: .
# Tag: .
# Head: has
# Dependency relation: punct
# Children: []

# %% [markdown]
# We can also quickly see spaCy's POS tagging in action by we using the displacy on doc2 with the style= parameter set to "dep" (short for dependency parsing):

# %%
# reimport all our stuff in case you're running this notebook as homework
from __future__ import unicode_literals
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

#Set some display options for the visualizer
options = {"compact": True, "distance": 90, "color": "yellow", "bg": "black", "font": "Gill Sans"}

displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="856c5e07091044b2bf46d74cd50063b8-0" class="displacy" width="3920" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: yellow; background: black; font-family: Gill Sans; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">beings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">equal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">dignity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">rights.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">endowed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">reason</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">conscience</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">should</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">act</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">towards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">spirit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </t

# %% [markdown]
# ### Using .subtree for extracting syntactic units
#
# Now that the above makes perfect sense (or your eyes are glazing over), let's learn how the `.subtree` attribute evaluates to a generator (remember that?!) that can be flatted by passing it to `list()`.
#
# In this case, the subtree is a list of the word's syntactic dependents--essentially, the clause that the word belongs to.

# %% [markdown]
# This function merges a subtree and returns a string with the text of the words contained in it:

# %%
def flatten_subtree(st):
       return ''.join([w.text_with_ws for w in list(st)]).strip() # just take my word for it!

# %% [markdown]
# With this function in our toolbox, we can write a loop that prints out the subtree for each word in a sentence:

# %%
for word in list(doc.sents)[2]:
    print("Word:", word.text)
    print("Flattened subtree: ", flatten_subtree(word.subtree))
    print("")
# Out:
# Word: Everyone
# Flattened subtree:  Everyone
#
# Word: has
# Flattened subtree:  Everyone has the right to life, liberty and security of person.
#
# Word: the
# Flattened subtree:  the
#
# Word: right
# Flattened subtree:  the right to life, liberty and security of person
#
# Word: to
# Flattened subtree:  to life, liberty and security of person
#
# Word: life
# Flattened subtree:  life, liberty and security of person
#
# Word: ,
# Flattened subtree:  ,
#
# Word: liberty
# Flattened subtree:  liberty and security of person
#
# Word: and
# Flattened subtree:  and
#
# Word: security
# Flattened subtree:  security
#
# Word: of
# Flattened subtree:  of person
#
# Word: person
# Flattened subtree:  person
#
# Word: .
# Flattened subtree:  .

# %% [markdown]
# Using the subtree and our knowledge of dependency relation types, we can write code that extracts larger syntactic units based on their relationship with the rest of the sentence. For example, to get all of the noun phrases that are subjects of a verb:

# %%
subjects = []
for word in doc:
    if word.dep_ in ('nsubj', 'nsubjpass'):
        subjects.append(flatten_subtree(word.subtree))

# %%
subjects
# Out:
# ['All human beings', 'They', 'Everyone']

# %% [markdown]
# Or every prepositional phrase:

# %%
prep_phrases = []
for word in doc:
    if word.dep_ == 'prep':
        prep_phrases.append(flatten_subtree(word.subtree))

# %%
prep_phrases
# Out:
# ['in dignity and rights',
#  'with reason and conscience',
#  'towards one another',
#  'in\na spirit of brotherhood',
#  'of brotherhood',
#  'to life, liberty and security of person',
#  'of person']

# %% [markdown]
# ###**Exercise #2**
#
# Modifying the code above, can you pull out the all of the prepositional phrases in the 2020 Democratic Party Platform?

# %%
# your code here

# %% [markdown]
# ### Putting the Pieces Together ###
#
# In "Connotation Frames of Power and Agency in Modern Films", and also in "Gender and Power in Japanese Light Fiction," both assigned for today, we saw how the combination of a particular part of speech--in those cases, verbs--combined with a lexcon (a slightly more content-ful dictionary) can be very illuminating.
#
# Now we're going to see what we can learn about the verbs in each party's platform--in particular, the "power" verbs that indicate power over the person/place/thing that the verb is doing something to.
#
# Reall that we've already learned how to 1) create a list of words that match a specific part of speech in a particular document; 2) lemmatize a particular word so that it is reduced to its root word; and 3) call a function that counts the number of words in a string that match a list of words in a (linguistic) dictionary.
#
# Now we're going to put the pieces together.

# %%
## This code cell creates a list of "power" verbs that we'll use a little later

# read in list of "power" verbs
resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall22/main/corpora/platforms/power-verbs.txt')
power_verbs = resp.text

# convert the verbs to a spacy object
power_verbs = nlp(power_verbs)

# then we're going to convert it to a list for easy comparisons,
# and in the process lemmatize the verbs for easy comparison
power_list = []

for verb in power_verbs:
  if "\n" not in verb.text:
    power_list.append(verb.lemma_)

# now you've got your list of power verbs to work with
# we'll just print out the lenght of the list so you
# get a sense of the numbers

# len(power_list)

power_list[0:9]
# Out:
# ['abandon',
#  'abolishe',
#  'absorb',
#  'abuse',
#  'accelerate',
#  'accept',
#  'access',
#  'accord',
#  'account']

# %%
# This code is very similar to code that you saw above. This is how we
# pull out all of the unique verbs in each of the documents:

rep_verbs = []
dem_verbs = []

for word in repub_plat_doc:
    if word.pos_ == 'VERB' and word.text not in rep_verbs:
        rep_verbs.append(word.text)

for word in dem_plat_doc:
    if word.pos_ == 'VERB' and word.text not in dem_verbs:
        dem_verbs.append(word.text)

print("Number of unique rep verbs: " + str(len(rep_verbs)))
print("Number of unique dem verbs: " + str(len(dem_verbs)))
# Out:
# Number of unique rep verbs: 433
# Number of unique dem verbs: 1629

# %% [markdown]
# But if we're going to compare these verbs to a list, we need to lemmatize them first to make sure that we're able to match the one to the other. Which brings us to...
#
# ### **Exercise 3**
#
# Using the code cell above as a guide, write some code such that instead of creating lists of all the unique *verbs* in each platform, we're creating lists of the unique verb *lemmas* in those platforms

# %%
rep_verb_lemmas = []
dem_verb_lemmas = []

# your code goes here

for word in repub_plat_doc:
    if word.pos_ == 'VERB' and word.lemma_ not in rep_verb_lemmas:
        rep_verb_lemmas.append(word.lemma_)

for word in dem_plat_doc:
    if word.pos_ == 'VERB' and word.lemma_ not in dem_verb_lemmas:
        dem_verb_lemmas.append(word.lemma_)

print("Number of unique rep lemmas: " + str(len(rep_verb_lemmas)))
print("Number of unique dem lemmas: " + str(len(dem_verb_lemmas)))
# Out:
# Number of unique rep lemmas: 289
# Number of unique dem lemmas: 888

# %% [markdown]
# Now that we've got our lemmas, we can use a basic counting function to count the number of power verbs used in each platform:

# %%
dem_count = 0
rep_count = 0

for verb in rep_verb_lemmas:
  if verb in power_list:
      rep_count += 1

for verb in dem_verb_lemmas:
  if verb in power_list:
      dem_count += 1

print("Number of power verbs:")
print("Dems: " + str(dem_count))
print("Repubs: " + str(rep_count))

print("\nPercentage of power verbs:")
print("Dems: " + str(dem_count / len(dem_verb_lemmas)))
print("Repubs: " + str(rep_count / len(rep_verb_lemmas)))
# Out:
# Number of power verbs:
# Dems: 413
# Repubs: 154
#
# Percentage of power verbs:
# Dems: 0.4650900900900901
# Repubs: 0.532871972318339

# %% [markdown]
# And one last exercise!
#
# ### **Exercise #4**
#
# In a sentence, what is one thing we can conclude about the power verbs used in the Democratic Party Platform vs. the Republican one?

# %%
# your answer here

# %% [markdown]
# ## Further reading and resources
#
# [A few example programs can be found here.](https://github.com/aparrish/rwet-examples/tree/master/spacy)
#
# We've barely scratched the surface of what it's possible to do with spaCy. [There's a great page of tutorials on the official site](https://spacy.io/docs/usage/tutorials) that you should check out!

# %% [markdown]
# *I wrote version 1.0 of this notebook based off materials by Alison Parrish. Dan Sinykin supplemented the 2020 version with material from Melanie Walsh's chapters [Named Entity Recognition](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Text-Analysis/Named-Entity-Recognition.html) and [Part-of-Speech Tagging](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Text-Analysis/POS-Keywords.html). For 2021, I've added material adapted from David Bamman's [Applied NLP](https://github.com/dbamman/anlp21) course, and revised the notebook again for 2022 and 2024.*
